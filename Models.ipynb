# %% [markdown]
# # Model Building
#
# In this notebook we will be building a few different models for our recommendation system. We will look into content-based, collaborative filtering, and a combined model (content-based collaborative filtering). We will spilt our data into training and testing sets.
#
# **The steps are as follows:**
# 1. Import Train and Test data
# 2.
#
# #### Import libraries/modules below:

# %%
import pickle
import re
import pandas as pd
import surprise
from surprise import KNNWithMeans
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import NormalPredictor
from surprise import KNNBaseline
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import BaselineOnly
from surprise import CoClustering
from surprise import SlopeOne
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise.reader import Reader
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from Mod_5_functions import pickle_file,open_pickle

# %% [markdown]
# #### Import the data:
# - Save it as a DataFrame.
# - For our __baseline Collaborative-Filtering Model__, lets create a brand new __DataFrame__ with *only* the **userUrl, rev_company_name, rev_company_url, and the star rating.**

# %%
user_reviews_train = open_pickle('Data/train_data')
user_reviews_test = open_pickle('Data/test_data')

# %%
bus_reviews_df
# Out:
#                                         rev_company_name  \
# 0             Planet Fitness - Manhattan - Canal St - NY
# 1                                      Montauk Salt Cave
# 2      Pure Barre - New York Columbus Circle - 60th &...
# 3      Return To Life Center - Pilates and Functional...
# 4                                                Peloton
# 5                                             Sonic Yoga
# 6                                       Daya Yoga Studio
# 7                                     Simply Fit Astoria
# 8                                 Exhale Upper East Side
# 9                                            Physique 57
# 10                                               Inscape
# 11                                        YogaWorks Soho
# 12                               The Bar Method - CLOSED
# 13                         Pure Barre - New York Tribeca
# 14                                        The Cobra Club
# 15                        The Rock Health & Fitness Club
# 16                                Kutsher’s Country Club
# 17                                               Peloton
# 18                                          Richie’s Gym
# 19                                    Yoga to the People
# 20                                  Pilates Union Square
# 21                                               Peloton
# 22                             New York Pilates - CLOSED
# 23                                   Cyc Fitness Chelsea
# 24                                           AQUA Studio
# 25                                               Peloton
# 26                                        SWERVE Fitness
# 27                                    Mile High Run Club
# 28                                           Physique 57
# 29                            Laughing Lotus Yoga Center
# ...                                                  ...
# 13231               Planet Fitness - Brooklyn - Bushwick
# 13232                              Blink Fitness - Gates
# 13233                     New York Sports Clubs - CLOSED
# 13234  The Radiant: Massage Therapy & Integrative Wel...
# 13235                                    Kosciuszko Pool
# 13236                  Bikram Yoga Williamsburg - CLOSED
# 13237                                    Kosciuszko Pool
# 13238                                    Kosciuszko Pool
# 13239                             Sheila Kelley S Factor
# 13240                                    Kosciuszko Pool
# 13241                       Long Island City Branch YMCA
# 13242                              New York Sports Clubs
# 13243                            Integral Yoga Institute
# 13244                               Djoniba Dance Centre
# 13245                                 Bikram Yoga Harlem
# 13246                               Djoniba Dance Centre
# 13247                           Salsa Salsa Dance Studio
# 13248                               Djoniba Dance Centre
# 13249                                      ANYA - CLOSED
# 13250                         Pilates Reforming New York
# 13251                 Pilates Reforming New York - MOVED
# 13252                               Djoniba Dance Centre
# 13242         39-01 Queens Blvd Sunnyside, NY 11104              3.0
# 13243              227 W 13th St New York, NY 10011              4.0
# 13244              126 E 13th St New York, NY 10003              2.0
# 13245             518 W 145th St New York, NY 10031              5.0
# 13246              126 E 13th St New York, NY 10003              2.0
# 13247                 55 4th Ave Brooklyn, NY 11217              5.0
# 13248              126 E 13th St New York, NY 10003              5.0
# 13249                            New York, NY 10010              4.0
# 13250              300 W 38th St New York, NY 10018              4.0
# 13251              130 W 42nd St New York, NY 10036              4.0
# 13252              126 E 13th St New York, NY 10003              4.0
# 13253                 90 John St New York, NY 10038              3.0
# 13254                640 Dean St Brooklyn, NY 11238              4.0
# 13255              126 E 13th St New York, NY 10003              3.0
# 13256              126 E 13th St New York, NY 10003              4.0
# 13257           310 Atlantic Ave Brooklyn, NY 11201              5.0
# 13258            2228 Church Ave Brooklyn, NY 11226              5.0
# 13259            2228 Church Ave Brooklyn, NY 11226              1.0
# 13260      1166 Coney Island Ave Brooklyn, NY 11230              1.0
#
#                                         rev_comp_reviews  \
# 0      Planet Fitness is an affordable, no frills gym...
# 1      I purchased a Groupon for a friend and I. When...
# 2      I enjoyed my class, but this was one of my lea...
# 3      I came in for their Pilates Mat Fundamental cl...
# 4      I came in for my first Peloton class awhile ba...
# 5      I found Sonic on Class Pass, it was a donation...
# 6      This is what I think of when I think of a ster...
# 7      Jesus! I signed up for their Burn the Barre cl...
# 8      Wow, this place is really gorgeous. I came for...
# 9      I think this was my favorite Barre class yet! ...
# 10     Two stars may seem harsh, as you'll see nothin...
# 11     I've been using Classpass for a few weeks now ...
# 12     I signed up for my first ever Barre class thro...
# 13     This is only my second Barre class but I loved...
# 14     Jesus I had so much fun here. I came to see Fo...
# 15     I had bought a Fitness Pass and one of the gym...
# 16     I grew up coming here and it makes me so sad t...
# 17     I've been an avid street cyclist (Brooklyn bor...
# 18     Richie's is an local old-school gym in the are...
# 19     Have been coming here with my friends ever sin...
# 20     This class is basically like physical therapy ...
# 21     Holy Moses you will be dead after this class. ...
# 22     I came here through ClassPass and I think you ...
# 23     TLDR; If you're looking for more dance and no ...
# 24     TLDR; Cool experience for the single class, bu...
# 25     Peloton: you are the best surprise YET! :)I've...
# 26     I came here about a few weeks after my last vi...
# 27     You know... I was hesitant to come here becaus...
# 28     I took my first class today and I'm totally a ...
# 29     I came here on NYD to take a class to get my n...
# ...                                                  ...
# 13231  I'm giving this place a good review (docked on...
# 13232  So far this has been one of the best gym exper...
# 13233  This is one of the smaller NYSC but one of the...
# 13234  Changchup is obviously very knowledgeable abou...
# 13235  I was so excited to try this pool especially a...
# 13236  I can't decide how many stars to give this pla...
# 13237  CLEAN AND FREEI've passed this pool for 2 year...
# 13238  I live in Bedstuy right around the corner from...
# 13239  I am now a level 4 S factor student and loving...
# 13240  I've swum in about 6 different public pools fo...
# 13241  I had a membership here over the summer - it's...
# 13242  I would have given this spot a 4 star rating b...
# 13243  I take the Yoga Level 1 class here and it's gr...
# 13244  Grunge. And sweat. And young people. I actuall...
# 13245  Price: $30 for unlimited classes for 30 days (...
# 13246  Price: $17Highlight: The live drummingI had a ...
# 13247  SalsaSalsa Dance Studio is an excellent place ...
# 13248  I have been attending Djoniba classes for abou...
# 13249  I really like this place.  The environment is ...
# 13250  I take classes at this location and 42nd stree...
# 13251  I purchased a deal for this place for 3 classe...
# 13252  I took a class here for fun with a friend.  We...
# 13253  Not my favorite Crunch location, but does the ...
# 13254  Came here for a spin class via Classpass. The ...
# 13255  I took an beginners class with Joneeba as my i...
# 13256  I took my first class here this past Saturday,...
# 13257  We absolutely loved learning to dance with Lau...
# 13258  Went in today and used the free day trial gues...
# 13259  I stopped by today 12 minutes before 7 this pa...
# 13260  This place is honestly a dump. The air conditi...
#
#                                                  userUrl  \
# 0      https://www.yelp.com/user_details?userid=exPhu...
# 1      https://www.yelp.com/user_details?userid=exPhu...
# 2      https://www.yelp.com/user_details?userid=exPhu...
# 3      https://www.yelp.com/user_details?userid=exPhu...
# 4      https://www.yelp.com/user_details?userid=exPhu...
# 5      https://www.yelp.com/user_details?userid=exPhu...
# 6      https://www.yelp.com/user_details?userid=exPhu...
# 7      https://www.yelp.com/user_details?userid=exPhu...
# 8      https://www.yelp.com/user_details?userid=exPhu...
# 9      https://www.yelp.com/user_details?userid=exPhu...
# 10     https://www.yelp.com/user_details?userid=exPhu...
# 11     https://www.yelp.com/user_details?userid=exPhu...
# 12     https://www.yelp.com/user_details?userid=exPhu...
# 13     https://www.yelp.com/user_details?userid=exPhu...
# 14     https://www.yelp.com/user_details?userid=exPhu...
# 15     https://www.yelp.com/user_details?userid=exPhu...
# 16     https://www.yelp.com/user_details?userid=exPhu...
# 17     https://www.yelp.com/user_details?userid=W-8nz...
# 18     https://www.yelp.com/user_details?userid=W-8nz...
# 19     https://www.yelp.com/user_details?userid=W-8nz...
# 20     https://www.yelp.com/user_details?userid=UL5kW...
# 21     https://www.yelp.com/user_details?userid=UL5kW...
# 22     https://www.yelp.com/user_details?userid=4AWL_...
# 23     https://www.yelp.com/user_details?userid=4AWL_...
# 24     https://www.yelp.com/user_details?userid=4AWL_...
# 25     https://www.yelp.com/user_details?userid=4AWL_...
# 26     https://www.yelp.com/user_details?userid=4AWL_...
# 27     https://www.yelp.com/user_details?userid=4AWL_...
# 28     https://www.yelp.com/user_details?userid=4AWL_...
# 29     https://www.yelp.com/user_details?userid=4AWL_...
# ...                                                  ...
# 13231  https://www.yelp.com/user_details?userid=j3gqv...
# 13232  https://www.yelp.com/user_details?userid=C-mwi...
# 13233  https://www.yelp.com/user_details?userid=C-mwi...
# 13234  https://www.yelp.com/user_details?userid=h2Y3r...
# 13235  https://www.yelp.com/user_details?userid=h2Y3r...
# 13236  https://www.yelp.com/user_details?userid=fAgW1...
# 13237  https://www.yelp.com/user_details?userid=fAgW1...
# 13238  https://www.yelp.com/user_details?userid=O1q-w...
# 13239  https://www.yelp.com/user_details?userid=O1q-w...
# 13240  https://www.yelp.com/user_details?userid=ZPQv0...
# 13241  https://www.yelp.com/user_details?userid=zCJE9...
# 13242  https://www.yelp.com/user_details?userid=zCJE9...
# 13243  https://www.yelp.com/user_details?userid=zCJE9...
# 13244  https://www.yelp.com/user_details?userid=zCJE9...
# 13245  https://www.yelp.com/user_details?userid=P24CY...
# 13246  https://www.yelp.com/user_details?userid=P24CY...
# 13247  https://www.yelp.com/user_details?userid=8dBMZ...
# 13248  https://www.yelp.com/user_details?userid=8dBMZ...
# 13249  https://www.yelp.com/user_details?userid=dZQut...
# 13250  https://www.yelp.com/user_details?userid=dZQut...
# 13251  https://www.yelp.com/user_details?userid=dZQut...
# 13252  https://www.yelp.com/user_details?userid=dZQut...
# 13253  https://www.yelp.com/user_details?userid=FgOci...
# 13254  https://www.yelp.com/user_details?userid=FgOci...
# 13255  https://www.yelp.com/user_details?userid=FgOci...
# 13256  https://www.yelp.com/user_details?userid=-GN5a...
# 13257  https://www.yelp.com/user_details?userid=_gY5m...
# 13258  https://www.yelp.com/user_details?userid=_gY5m...
# 13259  https://www.yelp.com/user_details?userid=y2ryc...
# 13260  https://www.yelp.com/user_details?userid=y2ryc...
#
#                                 comapny_source
# 0                                      Peloton
# 1                                      Peloton
# 2                                      Peloton
# 3                                      Peloton
# 4                                      Peloton
# 5                                      Peloton
# 6                                      Peloton
# 7                                      Peloton
# 8                                      Peloton
# 9                                      Peloton
# 10                                     Peloton
# 11                                     Peloton
# 12                                     Peloton
# 13                                     Peloton
# 14                                     Peloton
# 15                                     Peloton
# 16                                     Peloton
# 17                                     Peloton
# 18                                     Peloton
# 19                                     Peloton
# 20                                     Peloton
# 21                                     Peloton
# 22                                     Peloton
# 23                                     Peloton
# 24                                     Peloton
# 25                                     Peloton
# 26                                     Peloton
# 27                                     Peloton
# 28                                     Peloton
# 29                                     Peloton
# ...                                        ...
# 13231                    Blink Fitness - Gates
# 13232                    Blink Fitness - Gates
# 13233                    Blink Fitness - Gates
# 13234                          Kosciuszko Pool
# 13235                          Kosciuszko Pool
# 13236                          Kosciuszko Pool
# 13237                          Kosciuszko Pool
# 13238                          Kosciuszko Pool
# 13239                          Kosciuszko Pool
# 13240                          Kosciuszko Pool
# 13241                     Djoniba Dance Centre
# 13242                     Djoniba Dance Centre
# 13243                     Djoniba Dance Centre
# 13244                     Djoniba Dance Centre
# 13245                     Djoniba Dance Centre
# 13246                     Djoniba Dance Centre
# 13247                     Djoniba Dance Centre
# 13248                     Djoniba Dance Centre
# 13249                     Djoniba Dance Centre
# 13250                     Djoniba Dance Centre
# 13251                     Djoniba Dance Centre
# 13252                     Djoniba Dance Centre
# 13253                     Djoniba Dance Centre
# 13254                     Djoniba Dance Centre
# 13255                     Djoniba Dance Centre
# 13256                     Djoniba Dance Centre
# 13257  Planet Fitness - Brooklyn - Church Ave.
# 13258  Planet Fitness - Brooklyn - Church Ave.
# 13259  Planet Fitness - Brooklyn - Church Ave.
# 13260  Planet Fitness - Brooklyn - Church Ave.
#
# [13261 rows x 7 columns]

# %%
cf_rec_start_df = bus_reviews_df[['userUrl','rev_company_name','rev_comp_rating']]
cf_rec_user_start_df = user_reviews_df[['userUrl','rev_company_name','rev_comp_rating']]

# %% [markdown]
# #### To make a userId out of the Users' urls we will use regex to remove everything before the 'userid=':

# %%
s = 'userid\=(.*)'
cf_rec_start_df['user_id'] = cf_rec_start_df.userUrl.apply(lambda url: re.search(s, url).group(1))
cf_rec_user_start_df['user_id'] = cf_rec_user_start_df.userUrl.apply(lambda url: re.search(s, url).group(1))\
# Out:
# /Users/kghahremani/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/kghahremani/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
reader = Reader(rating_scale=(1, 5))
data_1 = Dataset.load_from_df(cf_rec_start_df[['user_id', 'rev_company_name','rev_comp_rating']], reader)
data_2 = Dataset.load_from_df(cf_rec_user_start_df[['user_id', 'rev_company_name','rev_comp_rating']], reader)

# %%
# define a cross-validation iterator
kf = KFold(n_splits=4)

algo = SlopeOne()

RMSE = []
for trainset, testset in kf.split(data):

    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    RMSE.append(accuracy.rmse(predictions))
    accuracy.rmse(predictions, verbose=True)
print(f'Average RSME: {sum(RMSE)/4}')
# Out:
# RMSE: 1.3918
# RMSE: 1.3918
# RMSE: 1.4134
# RMSE: 1.4134
# RMSE: 1.3921
# RMSE: 1.3921
# RMSE: 1.4226
# RMSE: 1.4226
# Average RSME: 1.4049471617782279

# %% [markdown]
# Now, that we have run a very basic SlopeOne model and recieved an averge Root Mean Squared Error (RMSE) of 1.41. This basiclly means that on averge we were almost a star and a half rating off. We can now try different combinations of the parameters to improve our model.

# %%
param_grid = {'n_epochs': [5, 10],'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}
gs = GridSearchCV(S, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.1923823868939172
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import GridSearchCV


param_grid = {'n_epochs': [5, 10,20], 'lr_all': [0.002, 0.005,0.006,0.1],
              'reg_all': [0.4, 0.6,0.2]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.1702228906310412
# {'n_epochs': 20, 'lr_all': 0.006, 'reg_all': 0.2}

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse  fit_time  test_time
# Algorithm
# SVDpp             1.167599  0.982693   0.064427
# SVD               1.169148  0.398672   0.019652
# BaselineOnly      1.179409  0.011756   0.014861
# KNNBaseline       1.246702  0.187133   0.095442
# KNNBasic          1.312642  0.171970   0.097058
# CoClustering      1.338433  0.354750   0.019541
# KNNWithMeans      1.372905  0.205766   0.093389
# KNNWithZScore     1.393994  0.224914   0.096295
# NMF               1.415371  0.487227   0.019075
# SlopeOne          1.415690  0.045959   0.027149
# NormalPredictor   1.688078  0.006776   0.015019

# %%
results_df = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')

# %%
results_df['test_rmse'].sort_values(ascending=True)
# Out:
# Algorithm
# SVDpp              1.167599
# SVD                1.169148
# BaselineOnly       1.179409
# KNNBaseline        1.246702
# KNNBasic           1.312642
# CoClustering       1.338433
# KNNWithMeans       1.372905
# KNNWithZScore      1.393994
# NMF                1.415371
# SlopeOne           1.415690
# NormalPredictor    1.688078
# Name: test_rmse, dtype: float64

# %% [markdown]
# Based on the RSME the __SVDpp, SVD and BaselineOnly__ models performed the best. So, next we will use a grid search to determine the best paarameters for each.
#
# #### SVDpp:

# %%
param_grid = {'n_epochs': [10,20,30,35,37], 'lr_all': [0.005,0.006,0.0001],
              'reg_all': [0.4, 0.6,0.2,0.1]}
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.1475706648976265
# {'n_epochs': 35, 'lr_all': 0.006, 'reg_all': 0.2}

# %%
param_grid = {'n_epochs': [35,37], 'lr_all': [0.005,0.006,0.0001],
              'reg_all': [0.4, 0.6,0.3,0.2,0.1]}
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.148258447023538
# {'n_epochs': 37, 'lr_all': 0.006, 'reg_all': 0.2}

# %%
param_grid = {'n_epochs': [35,37], 'lr_all': [0.006,0.007,0.008],
              'reg_all': [0.02,0.2,0.25]}
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.1454172362858182
# {'n_epochs': 35, 'lr_all': 0.007, 'reg_all': 0.2}

# %%
param_grid = {'n_epochs': [35,37], 'lr_all': [0.006,0.007,0.008],
              'reg_all': [0.02,0.2,0.25]}
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.1489518678888262
# {'n_epochs': 37, 'lr_all': 0.007, 'reg_all': 0.2}

# %% [markdown]
# __SVD:__

# %%
param_grid = {'n_epochs': [35,37], 'lr_all': [0.006,0.007,0.008],
              'reg_all': [0.02,0.2,0.25]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.146241602056299
# {'n_epochs': 37, 'lr_all': 0.008, 'reg_all': 0.2}

# %% [markdown]
# **BaselineOnly**
#
# We will break this into the two separate methods of how our baseline is estimated. The two methods are Alternating Least Squares (ALS), the default, and Stochastic Gradient Descent (SGD). The reason we want to do this is beacause the hyperparameters that are default for each method are very different.
#
# _First with ALS:_

# %%
param_grid = {'bsl_options': {'method': ['als'],
                              'reg_i': [2,5,7,10],
                             'reg_u':[2,5,7,15],
                             'n_epocha':[2,5, 7,10]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=5)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# 1.1496574591737345
# {'bsl_options': {'method': 'als', 'reg_i': 5, 'reg_u': 5, 'n_epocha': 2}}

# %% [markdown]
# After a few iterations the best parameters were:
# - RMSE: 1.1496574591737345 -- {'method': 'als', 'reg_i': 5, 'reg_u': 5, 'n_epocha': 2}
# - RMSE: 1.1462057653758768 -- {'method': 'als', 'reg_i': 3, 'reg_u': 3, 'n_epocha': 2}
# - RMSE: 1.1440607458981593 -- {'method': 'als', 'reg_i': 3, 'reg_u': 4, 'n_epocha': 2}

# %% [markdown]
# *Now, with SGD:*

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.01,0.02,0.1],
                             'learning_rate':[0.0005,0.005,0.05],
                             'n_epocha':[5,10,20]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=5)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.158127632783543
# {'bsl_options': {'method': 'sgd', 'reg': 0.01, 'learning_rate': 0.005, 'n_epocha': 5}}

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.01,0.001, 0.02,0.1],
                             'learning_rate':[0.0005,0.005,0.0055,0.05],
                             'n_epocha':[5,7,10]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=5)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.1575834525285615
# {'bsl_options': {'method': 'sgd', 'reg': 0.02, 'learning_rate': 0.0055, 'n_epocha': 5}}

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.01, 0.02,0.03],
                             'learning_rate':[0.0005,0.005,0.0055,0.0065],
                             'n_epocha':[5,7,10]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=5)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.1554158765879046
# {'bsl_options': {'method': 'sgd', 'reg': 0.03, 'learning_rate': 0.0065, 'n_epocha': 5}}

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.02,0.03,0.04],
                             'learning_rate':[0.0055,0.0065,0.01,0.02],
                             'n_epocha':[5,7,10]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=5)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.1472855429923368
# {'bsl_options': {'method': 'sgd', 'reg': 0.04, 'learning_rate': 0.01, 'n_epocha': 5}}

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.06,0.07,0.08],
                             'learning_rate':[0.095, 0.01,0.015],
                             'n_epocha':[3,4,5,6]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=10)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.142727250064263
# {'bsl_options': {'method': 'sgd', 'reg': 0.08, 'learning_rate': 0.01, 'n_epocha': 3}}

# %%
1.1483207108165303
{'bsl_options': {'method': 'sgd', 'reg': 0.06, 'learning_rate': 0.01, 'n_epocha': 3}}

1.1481766687458612
{'bsl_options': {'method': 'sgd', 'reg': 0.07, 'learning_rate': 0.01, 'n_epocha': 3}}

# %%
param_grid = {'bsl_options': {'method': ['sgd'],
                              'reg': [0.02,0.03,0.04],
                             'learning_rate':[0.0055,0.0065,0.01,0.02],
                             'n_epocha':[5,7,10]}}
gs = GridSearchCV(BaselineOnly, param_grid, cv=10)
# ['n_epochs': [5,10,15], 'reg_u': [10,15,20],'reg_i': [5,10,15],
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# 1.1440774630100503
# {'bsl_options': {'method': 'sgd', 'reg': 0.04, 'learning_rate': 0.01, 'n_epocha': 5}}

# %%
1.142727250064263
{'bsl_options': {'method': 'sgd', 'reg': 0.08, 'learning_rate': 0.01, 'n_epocha': 3}}

# %%
# define a cross-validation iterator
kf = KFold(n_splits=4)

algo = BaselineOnly(bsl_options = {'method': 'sgd', 'reg': 0.04, 'learning_rate': 0.01, 'n_epocha': 5})

RMSE = []
for trainset, testset in kf.split(data_2):

    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    RMSE.append(accuracy.rmse(predictions))
    accuracy.rmse(predictions, verbose=True)
print(f'Average RSME: {sum(RMSE)/4}')
# Out:
# Estimating biases using sgd...
# RMSE: 1.1714
# RMSE: 1.1714
# Estimating biases using sgd...
# RMSE: 1.1496
# RMSE: 1.1496
# Estimating biases using sgd...
# RMSE: 1.1493
# RMSE: 1.1493
# Estimating biases using sgd...
# RMSE: 1.1987
# RMSE: 1.1987
# Average RSME: 1.1672278350387413

# %%
# define a cross-validation iterator
kf = KFold(n_splits=4)

algo = BaselineOnly(bsl_options = {'method': 'sgd', 'reg': 0.08, 'learning_rate': 0.01, 'n_epocha': 3})

RMSE = []
for trainset, testset in kf.split(data_1):

    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    RMSE.append(accuracy.rmse(predictions))
    accuracy.rmse(predictions, verbose=True)
print(f'Average RSME: {sum(RMSE)/4}')
# Out:
# Estimating biases using sgd...
# RMSE: 1.1288
# RMSE: 1.1288
# Estimating biases using sgd...
# RMSE: 1.1448
# RMSE: 1.1448
# Estimating biases using sgd...
# RMSE: 1.1964
# RMSE: 1.1964
# Estimating biases using sgd...
# RMSE: 1.2002
# RMSE: 1.2002
# Average RSME: 1.1675393216037895

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data_1, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse  fit_time  test_time
# Algorithm
# SVDpp             1.183018  1.356832   0.087181
# SVD               1.192734  0.513061   0.050050
# BaselineOnly      1.197564  0.024373   0.025542
# KNNBaseline       1.261663  0.298065   0.143570
# CoClustering      1.359149  0.472371   0.021606
# KNNBasic          1.359378  0.266807   0.119924
# KNNWithMeans      1.420546  0.263939   0.128129
# KNNWithZScore     1.426252  0.380006   0.136302
# NMF               1.447343  0.687014   0.024335
# SlopeOne          1.452812  0.061289   0.037372
# NormalPredictor   1.717046  0.010991   0.024958

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data_2, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse  fit_time  test_time
# Algorithm
# SVDpp             1.188804  1.401140   0.083129
# SVD               1.192334  0.487798   0.040390
# BaselineOnly      1.197520  0.021505   0.024233
# KNNBaseline       1.260038  0.316333   0.134988
# KNNBasic          1.357664  0.285997   0.122714
# CoClustering      1.363180  0.482785   0.023675
# KNNWithMeans      1.412170  0.367580   0.149964
# KNNWithZScore     1.422411  0.436025   0.155470
# SlopeOne          1.432825  0.065540   0.033384
# NMF               1.451937  0.757060   0.038958
# NormalPredictor   1.704070  0.013199   0.025415

# %% [markdown]
# TF-IDF Cosine Similarity Recommedation:

# %%
tfidf_matrix = open_pickle('Data/tfidf_reviews_matrix')
reviews_df = open_pickle('Data/reviews_w_new_sentiment')

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim_2 = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
sim_scores_2[89],sim_scores[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-10a214d6f461> in <module>()
# ----> 1 sim_scores_2[89],sim_scores[6]
#
# IndexError: list index out of range

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(reviews_df.index, index=reviews_df['rev_company_name']).drop_duplicates()

# %%
from scipy.spatial.distance import minkowski
idx = indices['Peloton']
sim_scores_2 = list(enumerate(cosine_sim_2[idx]))
sim_scores_2 = sorted(sim_scores, key=lambda x: sum(x[1]), reverse=True)

# %%
sim_scores_2 = sim_scores[1:11]

# %%
fit_indices = [i[0] for i in sim_scores_2]
reviews_df['rev_company_name'].iloc[fit_indices]
# Out:
# 72                   LA Fitness
# 91            TITLE Boxing Club
# 52                  WOOM CENTER
# 42               CorePower Yoga
# 80          Equinox Bryant Park
# 22    New York Pilates - CLOSED
# 69                    Solidcore
# 5                    Sonic Yoga
# 49                SKY TING YOGA
# Name: rev_company_name, dtype: object

# %%
# Function that takes in movie title as input and outputs most similar movies
from scipy.spatial.distance import minkowski
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: sum(x[1]), reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    fit_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return reviews_df['rev_company_name'].iloc[fit_indices]

# %%
# from scipy.stats import rankdata
# from numpy.random import rand
# from scipy.sparse import coo_matrix
from scipy.sparse import csr_matrix

cosine_df = pd.DataFrame(csr_matrix.todok(cosine_similarities))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-bb9b7c17fcb1> in <module>()
#       4 from scipy.sparse import csr_matrix
#       5
# ----> 6 cosine_df = pd.DataFrame(csr_matrix.todok(cosine_similarities))
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/base.py in todok(self, copy)
#     841         the resultant dok_matrix.
#     842         """
# --> 843         return self.tocoo(copy=copy).todok(copy=False)
#     844
#     845     def tocoo(self, copy=False):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/coo.py in todok(self, copy)
#     384         from .dok import dok_matrix
#     385
# --> 386         self.sum_duplicates()
#     387         dok = dok_matrix((self.shape), dtype=self.dtype)
#     388         dok._update(izip(izip(self.row,self.col),self.data))
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/coo.py in sum_duplicates(self)
#     469         if self.has_canonical_format:
#     470             return
# --> 471         summed = self._sum_duplicates(self.row, self.col, self.data)
#     472         self.row, self.col, self.data = summed
#     473         self.has_canonical_format = True
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/coo.py in _sum_duplicates(self, row, col, data)
#     480         row = row[order]
#     481         col = col[order]
# --> 482         data = data[order]
#     483         unique_mask = ((row[1:] != row[:-1]) |
#     484                        (col[1:] != col[:-1]))
#
# KeyboardInterrupt:

# %%
cosine_similarities[0].indece
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-d8fb0af712a7> in <module>()
# ----> 1 cosine_similarities[0].indece
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     645             return self.getnnz()
#     646         else:
# --> 647             raise AttributeError(attr + " not found")
#     648
#     649     def transpose(self, axes=None, copy=False):
#
# AttributeError: indece not found

# %%
# # import pandas as pd
# import numpy as np
# from numpy import argsort
# # from sklearn.feature_extraction.text import TfidfVectorizer
# # from sklearn.metrics.pairwise import cosine_similarity
# # reviews_df['rev_company_name'] #names of companies

from itertools import izip

def sort_coo(m):
    tuples = izip(m.row, m.col, m.data)
    return sorted(tuples, key=lambda x: (x[0], x[2]))

# cosine_similarities = cosine_similarity(tfidf_matrix,Y=None,dense_output=False)
results = {} # dictionary created to store the result in a dictionary format (ID : (Score,item_id))#
for idx, row in reviews_df.iterrows(): #iterates through all the rows

# the below code 'similar_indice' stores similar ids based on cosine similarity. sorts them in ascending order. [:-5:-1] is then used so that the indices with most similarity are got. 0 means no similarity and 1 means perfect similarity#
    similar_indices = sort_coo(cosine_similarities[idx])

    #stores 5 most similar books, you can change it as per your needs
    similar_items = [(cosine_similarities[idx][i], reviews_df['rev_company_name'][i]) for i in similar_indices]
    results[row['rev_company_name']] = similar_items[1:]
    
#below code 'function item(id)' returns a row matching the id along with Book Title. Initially it is a dataframe, then we convert it to a list#
def item(name):
    return reviews_df.loc[reviews_df['rev_company_name'] == name]['rev_company_name'].tolist()[0]
def recommend(name, num):
    if (num == 0):
        print("Unable to recommend any book as you have not chosen the number of book to be recommended")
    elif (num==1):
        print("Recommending " + str(num) + " book similar to " + item(name))
        
    else :
        print("Recommending " + str(num) + " books similar to " + item(name))
        
    print("----------------------------------------------------------")
    recs = results[name][:num]
    for rec in recs:
        print("You may also like to read: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

#the first argument in the below function to be passed is the id of the book, second argument is the number of books you want to be recommended#
recommend('Peloton',2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-f69e3025fdd8> in <module>()
#      16
#      17     #stores 5 most similar books, you can change it as per your needs
# ---> 18     similar_items = [(cosine_similarities[idx][i], reviews_df['rev_company_name'][i]) for i in similar_indices]
#      19     results[row['rev_company_name']] = similar_items[1:]
#      20
#
# <ipython-input-94-f69e3025fdd8> in <listcomp>(.0)
#      16
#      17     #stores 5 most similar books, you can change it as per your needs
# ---> 18     similar_items = [(cosine_similarities[idx][i], reviews_df['rev_company_name'][i]) for i in similar_indices]
#      19     results[row['rev_company_name']] = similar_items[1:]
#      20
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     331         if not (issequence(col) and issequence(row)):
#     332             # Sample elementwise
# --> 333             row, col = self._index_to_arrays(row, col)
#     334
#     335         row = asindices(row)
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/sputils.py in _index_to_arrays(self, i, j)
#     363                 i = i[:, None]
#     364             elif not i_slice:
# --> 365                 raise IndexError('index returns 3-dim structure')
#     366         elif isscalarlike(j):
#     367             # row vector special case
#
# IndexError: index returns 3-dim structure

# %%
indices = pd.Series(reviews_df.index)

#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations(comp_name, cosine_sim = cosine_sim):
    
    # initializing the empty list of recommended movies
    recommended_fit = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == comp_name.index]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in top_10_indexes:
        recommended_fit.append(list( reviews_df.index)[i])
        
    return recommended_fit

recommendations('Peloton', cosine_similarities)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-3b4e6b0428ca> in <module>()
#      23     return recommended_fit
#      24
# ---> 25 recommendations('Peloton', cosine_similarities)
#
# <ipython-input-160-3b4e6b0428ca> in recommendations(comp_name, cosine_sim)
#      12
#      13     # creating a Series with the similarity scores in descending order
# ---> 14     score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
#      15
#      16     # getting the indexes of the 10 most similar movies
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     251                 if not is_list_like(data):
#     252                     data = [data]
# --> 253                 index = _default_index(len(data))
#     254
#     255             # create/copy the manager
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/base.py in __len__(self)
#     264     # non-zeros is more important.  For now, raise an exception!
#     265     def __len__(self):
# --> 266         raise TypeError("sparse matrix length is ambiguous; use getnnz()"
#     267                         " or shape[0]")
#     268
#
# TypeError: sparse matrix length is ambiguous; use getnnz() or shape[0]

# %%
list(zip(cosine_similarities[0].indices,cosine_similarities[0].data)).sort(key=lambda tup: tup[1])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarities = cosine_similarity(tfidf_matrix,Y=None,dense_output=False)

# %%
# results = {} 
# for idx, row in reviews_df.iterrows(): #iterates through all the rows
#     similar_zip = list(zip(cosine_similarities[0].indices,cosine_similarities[0].data)).sort(key=lambda tup: tup[1])
#     similar_indices = [i[0] for i in sorted(test,key = lambda tupe: tupe[1], reverse=True)][1:]
    
#     similar_items = [reviews_df['rev_company_name'][i] for i in similar_indices]
#     results[row['rev_company_name']] = similar_items
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-077415ff3ce0> in <module>()
#       4     similar_indices = [i[0] for i in sorted(test,key = lambda tupe: tupe[1], reverse=True)][1:]
#       5
# ----> 6     similar_items = [reviews_df['rev_company_name'][i] for i in similar_indices]
#       7     results[row['rev_company_name']] = similar_items
#       8
#
# <ipython-input-33-077415ff3ce0> in <listcomp>(.0)
#       4     similar_indices = [i[0] for i in sorted(test,key = lambda tupe: tupe[1], reverse=True)][1:]
#       5
# ----> 6     similar_items = [reviews_df['rev_company_name'][i] for i in similar_indices]
#       7     results[row['rev_company_name']] = similar_items
#       8
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2543         # if we have something that is Index-like, then
#    2544         # use this, e.g. DatetimeIndex
# -> 2545         s = getattr(series, '_values', None)
#    2546         if isinstance(s, Index) and is_scalar(key):
#    2547             try:
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/series.py in _values(self)
#     401     def _values(self):
#     402         """ return the internal repr of this data """
# --> 403         return self._data.internal_values()
#     404
#     405     def _formatting_values(self):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in internal_values(self)
#    4505
#    4506     def internal_values(self):
# -> 4507         return self._block.internal_values()
#    4508
#    4509     def formatting_values(self):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in _block(self)
#    4407         pass
#    4408
# -> 4409     @property
#    4410     def _block(self):
#    4411         return self.blocks[0]
#
# KeyboardInterrupt:

# %%
def item(name):
    return reviews_df.loc[reviews_df['rev_company_name'] == name]['rev_company_name'].tolist()[0]
def recommend(name, num):
    if (num == 0):
        print("Unable to recommend any book as you have not chosen the number of book to be recommended")
    elif (num==1):
        print("Recommending " + str(num) + " book similar to " + item(name))
        
    else :
        print("Recommending " + str(num) + " books similar to " + item(name))
        
    print("----------------------------------------------------------")
    recs = results[name][:num]
    for rec in recs:
        print("You may also like to read: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")


recommend('Peloton',2)

# %%
here = list(zip(cosine_similarities[0].indices,cosine_similarities[0].data)).sort(key=lambda tup: tup[1])

# %%
list(zip(list(cosine_similarities[0].indices),list(cosine_similarities[0].data)))
# Out:
# [(9698, 0.009278498439621207),
#  (14993, 0.008635076627653037),
#  (14145, 0.0045644651284599954),
#  (13492, 0.003700166578920376),
#  (13055, 0.0061381977254084605),
#  (12948, 0.0031281606449373423),
#  (11102, 0.00177881918106044),
#  (6570, 0.003557991556167144),
#  (6176, 0.003429729180667422),
#  (4912, 0.0025100424298534194),
#  (3867, 0.005529410684540945),
#  (10020, 0.04042510227107501),
#  (10366, 0.023092322355937604),
#  (8215, 0.015323992475893075),
#  (5420, 0.010397902580397888),
#  (10690, 0.03412650259852396),
#  (10680, 0.027993665830280408),
#  (10614, 0.022049333183100477),
#  (10605, 0.010417021938764313),
#  (10586, 0.06585943316684399),
#  (10568, 0.03060857213971001),
#  (10559, 0.030279599195419633),
#  (10553, 0.006148100554527164),
#  (10533, 0.05212668009792934),
#  (10504, 0.0565731328021254),
#  (10497, 0.028622158318606747),
#  (10465, 0.06802896157728132),
#  (10423, 0.024537046772997412),
#  (10392, 0.021820849306795145),
#  (10345, 0.013013927871000867),
#  (10314, 0.008204589563908708),
#  (10288, 0.060523958204001985),
#  (10256, 0.013939992649605007),
#  (10169, 0.027454794597927917),
#  (9943, 0.016443823090619075),
#  (9878, 0.03665741783381687),
#  (9793, 0.012008972258554185),
#  (9792, 0.02411967817389782),
#  (9704, 0.010483155133298993),
#  (9667, 0.03874353568753637),
#  (9627, 0.02939834964200758),
#  (9612, 0.04444469688813836),
#  (9600, 0.03947939552432169),
#  (9598, 0.07402924107310652),
#  (9556, 0.016221518368494416),
#  (9490, 0.04206988000581569),
#  (9475, 0.026274867968266218),
#  (9460, 0.009497741955553437),
#  (9459, 0.018217016026992452),
#  (9390, 0.0356902839638413),
#  (9387, 0.0416490935848618),
#  (9282, 0.025085632582821763),
#  (9276, 0.028073254626953842),
#  (9236, 0.07076127236031118),
#  (9229, 0.07441904301127523),
#  (9189, 0.07078878623611512),
#  (9182, 0.019815677235471965),
#  (9133, 0.05046812271416051),
#  (9127, 0.041034540551769916),
#  (9126, 0.01927178548484429),
#  (9111, 0.02299883621085712),
#  (9089, 0.014815474882545008),
#  (9063, 0.014646051414758846),
#  (9056, 0.0626671115520332),
#  (8986, 0.042610929809844836),
#  (8960, 0.04578848219754374),
#  (8942, 0.009619211778272256),
#  (8858, 0.01771691124348728),
#  (8805, 0.028397700028813384),
#  (8778, 0.03144978157778588),
#  (8737, 0.025438201470160387),
#  (8725, 0.030850196154998177),
#  (8714, 0.06752701054388138),
#  (8640, 0.09032975651240335),
#  (8597, 0.042620808388200725),
#  (8569, 0.0172199594430168),
#  (8553, 0.03970416439760074),
#  (8509, 0.029271844370439185),
#  (8465, 0.012319675807672938),
#  (8443, 0.02968100955000248),
#  (8410, 0.03004701119414745),
#  (8359, 0.11323040964785784),
#  (8348, 0.029048429603192514),
#  (8254, 0.03171165507983326),
#  (8177, 0.043460730050236616),
#  (8174, 0.04096073339151181),
#  (8153, 0.02273563857102685),
#  (8125, 0.03083964325604),
#  (8114, 0.01990551396965122),
#  (8089, 0.04162406719869396),
#  (8081, 0.03881278889208499),
#  (8024, 0.018072157177360604),
#  ...]

# %%
test = list(zip(list(cosine_similarities[0].indices),list(cosine_similarities[0].data)))

# %%
[i[0] for i in sorted(test,key = lambda tupe: tupe[1], reverse=True)][1:]
# Out:
# [12632,
#  6955,
#  70,
#  8860,
#  14438,
#  10548,
#  15356,
#  10114,
#  9803,
#  5306,
#  4014,
#  1197,
#  3068,
#  6178,
#  11573,
#  1794,
#  6011,
#  6007,
#  1799,
#  7030,
#  14838,
#  7033,
#  8667,
#  10502,
#  14431,
#  2770,
#  10239,
#  1203,
#  8350,
#  6901,
#  9423,
#  12331,
#  10676,
#  15343,
#  2907,
#  7934,
#  2983,
#  9832,
#  6004,
#  7925,
#  10704,
#  13638,
#  14003,
#  3899,
#  11750,
#  5720,
#  11922,
#  9432,
#  1843,
#  14422,
#  9529,
#  11485,
#  7196,
#  9695,
#  8228,
#  2982,
#  8669,
#  14840,
#  15662,
#  4441,
#  113,
#  544,
#  10549,
#  421,
#  11889,
#  890,
#  1233,
#  8668,
#  8304,
#  10547,
#  8064,
#  3427,
#  11768,
#  4644,
#  3330,
#  1814,
#  10812,
#  9971,
#  1449,
#  15200,
#  1807,
#  2647,
#  9408,
#  7032,
#  10746,
#  13478,
#  2667,
#  6781,
#  6527,
#  15413,
#  12363,
#  10648,
#  190,
#  11753,
#  6484,
#  7817,
#  12033,
#  4343,
#  11737,
#  1231,
#  10838,
#  3372,
#  10791,
#  6098,
#  13445,
#  7368,
#  12713,
#  5744,
#  12387,
#  15181,
#  8656,
#  15201,
#  13222,
#  7794,
#  5361,
#  8208,
#  10013,
#  9045,
#  10473,
#  14516,
#  6526,
#  3100,
#  7370,
#  6009,
#  6588,
#  2899,
#  8851,
#  13899,
#  7283,
#  125,
#  9938,
#  10466,
#  12368,
#  10052,
#  5672,
#  13789,
#  12704,
#  2804,
#  12163,
#  8347,
#  10778,
#  11679,
#  15324,
#  7716,
#  5490,
#  11023,
#  1314,
#  13916,
#  11270,
#  8671,
#  1798,
#  6734,
#  11754,
#  3415,
#  14487,
#  12150,
#  2906,
#  8338,
#  2782,
#  3325,
#  12375,
#  13564,
#  12742,
#  6657,
#  10488,
#  14917,
#  3129,
#  3246,
#  15677,
#  12177,
#  12364,
#  901,
#  14015,
#  3276,
#  4215,
#  8306,
#  9289,
#  7097,
#  8533,
#  11910,
#  5797,
#  9575,
#  1215,
#  10790,
#  10664,
#  7432,
#  9528,
#  8433,
#  7250,
#  10631,
#  11543,
#  10800,
#  15148,
#  15652,
#  2131,
#  3141,
#  11453,
#  8408,
#  2341,
#  9551,
#  4684,
#  11855,
#  15,
#  14980,
#  12362,
#  6622,
#  1805,
#  3328,
#  571,
#  13296,
#  8310,
#  2135,
#  4298,
#  3352,
#  11154,
#  358,
#  14414,
#  12648,
#  13338,
#  15141,
#  15298,
#  12155,
#  5101,
#  3270,
#  15715,
#  3531,
#  10399,
#  12709,
#  10476,
#  3240,
#  13300,
#  8461,
#  3683,
#  4634,
#  11198,
#  8822,
#  114,
#  8240,
#  8303,
#  9951,
#  12660,
#  9766,
#  14655,
#  6540,
#  13943,
#  9405,
#  12907,
#  7385,
#  14123,
#  4347,
#  2919,
#  12562,
#  12697,
#  5687,
#  9424,
#  3347,
#  9722,
#  13441,
#  105,
#  14785,
#  12382,
#  9701,
#  3413,
#  2877,
#  14087,
#  14859,
#  4800,
#  1950,
#  8653,
#  10501,
#  14735,
#  10585,
#  13201,
#  1207,
#  15571,
#  4050,
#  8409,
#  8920,
#  10172,
#  7891,
#  11627,
#  9663,
#  4374,
#  8110,
#  10436,
#  14793,
#  374,
#  6249,
#  2812,
#  6629,
#  6401,
#  3293,
#  11484,
#  15711,
#  4873,
#  6311,
#  14849,
#  6648,
#  6650,
#  15182,
#  14536,
#  4336,
#  7162,
#  3217,
#  6085,
#  3070,
#  13334,
#  13302,
#  6500,
#  15147,
#  4948,
#  1888,
#  5443,
#  4786,
#  9544,
#  12643,
#  5620,
#  2161,
#  8633,
#  2769,
#  13304,
#  10385,
#  8787,
#  13360,
#  4640,
#  1812,
#  15276,
#  8149,
#  10211,
#  2817,
#  13755,
#  11274,
#  2098,
#  3069,
#  15699,
#  7053,
#  7175,
#  7590,
#  2926,
#  14531,
#  63,
#  10542,
#  595,
#  14230,
#  15135,
#  12029,
#  15189,
#  6600,
#  11555,
#  12749,
#  15193,
#  7319,
#  9721,
#  1404,
#  81,
#  5793,
#  8378,
#  1815,
#  1209,
#  3412,
#  11235,
#  8693,
#  1235,
#  10147,
#  6533,
#  11747,
#  211,
#  3474,
#  5953,
#  6903,
#  157,
#  4942,
#  5686,
#  11258,
#  10390,
#  15336,
#  3502,
#  1182,
#  10273,
#  11338,
#  9884,
#  8952,
#  7345,
#  12077,
#  1933,
#  4173,
#  13206,
#  568,
#  12270,
#  9381,
#  9945,
#  12570,
#  854,
#  8836,
#  947,
#  3050,
#  13516,
#  873,
#  11860,
#  5610,
#  6752,
#  3493,
#  2789,
#  1795,
#  576,
#  6035,
#  15440,
#  5772,
#  11248,
#  9868,
#  4831,
#  15044,
#  11131,
#  4586,
#  2553,
#  13297,
#  9645,
#  4582,
#  6459,
#  12074,
#  9034,
#  12277,
#  9685,
#  10426,
#  11854,
#  11676,
#  7301,
#  49,
#  14490,
#  3368,
#  4872,
#  9768,
#  12051,
#  14527,
#  6750,
#  10440,
#  10868,
#  15211,
#  12673,
#  6736,
#  850,
#  11977,
#  6669,
#  11371,
#  1074,
#  7819,
#  5261,
#  12741,
#  8309,
#  13468,
#  6641,
#  9897,
#  14415,
#  410,
#  5355,
#  11122,
#  13661,
#  8957,
#  9636,
#  142,
#  12103,
#  2349,
#  7377,
#  4941,
#  6084,
#  9724,
#  692,
#  9422,
#  186,
#  12073,
#  15640,
#  9419,
#  14743,
#  12283,
#  11752,
#  10793,
#  9365,
#  11293,
#  13543,
#  6356,
#  861,
#  15696,
#  1816,
#  11853,
#  8685,
#  8325,
#  12354,
#  3096,
#  2242,
#  3501,
#  482,
#  7379,
#  3233,
#  2344,
#  2509,
#  3685,
#  12636,
#  10043,
#  3875,
#  13435,
#  12107,
#  11517,
#  3355,
#  9929,
#  2346,
#  12108,
#  8664,
#  9796,
#  6006,
#  10826,
#  11567,
#  1388,
#  3996,
#  12131,
#  4945,
#  8222,
#  10051,
#  10618,
#  1657,
#  13875,
#  6032,
#  13464,
#  1977,
#  3362,
#  14722,
#  1803,
#  11137,
#  14148,
#  8316,
#  6897,
#  6651,
#  6929,
#  5690,
#  8991,
#  8852,
#  3160,
#  9800,
#  10682,
#  5479,
#  13351,
#  4653,
#  4339,
#  9095,
#  8301,
#  8676,
#  3075,
#  14553,
#  10334,
#  4340,
#  6649,
#  4510,
#  5065,
#  4089,
#  5307,
#  9719,
#  3224,
#  722,
#  3726,
#  2193,
#  15708,
#  9833,
#  7528,
#  8776,
#  415,
#  8799,
#  12999,
#  2554,
#  5066,
#  931,
#  12061,
#  11582,
#  7025,
#  4056,
#  4530,
#  10023,
#  13394,
#  6046,
#  6815,
#  9399,
#  11793,
#  3773,
#  3503,
#  4446,
#  10195,
#  5417,
#  3205,
#  922,
#  1386,
#  1939,
#  15244,
#  1216,
#  2934,
#  9222,
#  6996,
#  3169,
#  13870,
#  12128,
#  11897,
#  2582,
#  7515,
#  12664,
#  12359,
#  4595,
#  4186,
#  9837,
#  3348,
#  9597,
#  7317,
#  1224,
#  10539,
#  12149,
#  5726,
#  3024,
#  3067,
#  12611,
#  15192,
#  12420,
#  606,
#  4250,
#  10702,
#  6403,
#  9039,
#  13548,
#  6762,
#  146,
#  11161,
#  13751,
#  13419,
#  9970,
#  8402,
#  3353,
#  13476,
#  4013,
#  2388,
#  5888,
#  10325,
#  2726,
#  10117,
#  15526,
#  13616,
#  13335,
#  10875,
#  9925,
#  8687,
#  5825,
#  2021,
#  4593,
#  10523,
#  13951,
#  4755,
#  12242,
#  6894,
#  2247,
#  12348,
#  15702,
#  14949,
#  6556,
#  2035,
#  7372,
#  9171,
#  13930,
#  8534,
#  1709,
#  10681,
#  14430,
#  3394,
#  1069,
#  12236,
#  7260,
#  880,
#  10551,
#  2086,
#  9094,
#  9881,
#  3093,
#  15251,
#  14534,
#  15460,
#  189,
#  15704,
#  7479,
#  4345,
#  15602,
#  5873,
#  4772,
#  1341,
#  6388,
#  3389,
#  12618,
#  5057,
#  2620,
#  3884,
#  9802,
#  3679,
#  10310,
#  2908,
#  10819,
#  1228,
#  2353,
#  5850,
#  10610,
#  15670,
#  720,
#  8816,
#  185,
#  9037,
#  13437,
#  3605,
#  15183,
#  15446,
#  10853,
#  14441,
#  2345,
#  6751,
#  2245,
#  14509,
#  13954,
#  10007,
#  1707,
#  12650,
#  12105,
#  3730,
#  11549,
#  3509,
#  8405,
#  4939,
#  9628,
#  10638,
#  8842,
#  13025,
#  2671,
#  827,
#  1290,
#  3482,
#  1367,
#  9402,
#  5945,
#  2203,
#  1640,
#  6761,
#  3341,
#  8574,
#  8531,
#  2826,
#  10472,
#  15232,
#  7163,
#  11024,
#  6638,
#  9987,
#  11273,
#  7417,
#  11554,
#  1023,
#  13353,
#  12619,
#  767,
#  12394,
#  2643,
#  345,
#  121,
#  1090,
#  7583,
#  471,
#  8319,
#  1368,
#  327,
#  14517,
#  11904,
#  5878,
#  12740,
#  4427,
#  1587,
#  3937,
#  6404,
#  13103,
#  9513,
#  11,
#  15243,
#  15473,
#  2496,
#  9178,
#  7090,
#  3697,
#  5517,
#  965,
#  8773,
#  13869,
#  10515,
#  962,
#  6017,
#  1222,
#  2201,
#  13215,
#  13466,
#  2589,
#  3637,
#  12016,
#  7268,
#  13059,
#  15540,
#  14573,
#  14089,
#  11988,
#  15445,
#  2471,
#  9288,
#  2592,
#  7670,
#  13945,
#  3970,
#  14590,
#  15133,
#  9739,
#  10041,
#  830,
#  9664,
#  2311,
#  7814,
#  13165,
#  690,
#  1232,
#  8763,
#  12698,
#  970,
#  9984,
#  12336,
#  1417,
#  1504,
#  9781,
#  1015,
#  12631,
#  10449,
#  12371,
#  11215,
#  15279,
#  13793,
#  8065,
#  4435,
#  4878,
#  7169,
#  13657,
#  12281,
#  11508,
#  3807,
#  7960,
#  11914,
#  6895,
#  10073,
#  4677,
#  14845,
#  4439,
#  9788,
#  13611,
#  14520,
#  760,
#  6143,
#  9941,
#  3498,
#  8665,
#  14769,
#  14857,
#  11292,
#  4363,
#  1796,
#  7230,
#  9510,
#  12540,
#  14432,
#  11927,
#  11784,
#  1825,
#  5528,
#  14024,
#  14401,
#  1782,
#  11069,
#  24,
#  11370,
#  10707,
#  11187,
#  11986,
#  2914,
#  2591,
#  3369,
#  2790,
#  6057,
#  11376,
#  4705,
#  2377,
#  391,
#  9433,
#  2374,
#  8399,
#  2339,
#  3542,
#  15213,
#  4067,
#  4369,
#  13327,
#  2240,
#  4057,
#  143,
#  9401,
#  15241,
#  2691,
#  10870,
#  6420,
#  13320,
#  14069,
#  11644,
#  1442,
#  820,
#  2502,
#  8614,
#  9434,
#  9828,
#  13756,
#  11738,
#  7022,
#  7486,
#  4621,
#  14791,
#  7119,
#  3247,
#  3349,
#  3239,
#  12194,
#  9769,
#  3199,
#  6759,
#  6224,
#  14400,
#  4313,
#  8751,
#  10004,
#  5374,
#  12897,
#  14492,
#  5492,
#  1804,
#  1543,
#  7330,
#  15010,
#  2697,
#  4285,
#  4154,
#  8492,
#  8491,
#  11044,
#  1146,
#  12528,
#  13228,
#  5623,
#  7547,
#  14329,
#  9574,
#  1779,
#  924,
#  13639,
#  10467,
#  1221,
#  11908,
#  15690,
#  420,
#  5876,
#  7777,
#  14786,
#  5962,
#  5749,
#  5532,
#  14528,
#  5226,
#  2791,
#  8286,
#  11905,
#  764,
#  11498,
#  15682,
#  4993,
#  1340,
#  4975,
#  8800,
#  14532,
#  7956,
#  4319,
#  4756,
#  9930,
#  13507,
#  13888,
#  9322,
#  8902,
#  12343,
#  7904,
#  739,
#  15190,
#  5628,
#  4879,
#  11861,
#  10858,
#  ...]

# %%
reviews_df['rev_company_name'][12632]
# Out:
# 'Blink Fitness - Chelsea'

# %%
similar_items
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-1ee6705b3c43> in <module>()
# ----> 1 cosine_similarities[0][12632]
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     290             # [i, 1:2]
#     291             elif isinstance(col, slice):
# --> 292                 return self._get_row_slice(row, col)
#     293             # [i, [1, 2]]
#     294             elif issequence(col):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/csr.py in _get_row_slice(self, i, cslice)
#     397
#     398         if i < 0 or i >= M:
# --> 399             raise IndexError('index (%d) out of range' % i)
#     400
#     401         start, stop, stride = cslice.indices(N)
#
# IndexError: index (12632) out of range
