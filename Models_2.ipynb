# %% [markdown]
# # Models Part 2 : Hybrids, NLP and More...
#
# In this notebook we will be building a few different models for our recommendation system.
#
# In our first models we tried some baseline models with only the original user reviews. In this notebook we will go deeper using our reviews to get suggestions (using TF-IDF). By the end of this, we need to combine our content based models and our collaborative-filtering model to get a hybrid model.
#
# **The steps are as follows:**
# 1. Import Train and Test data
# 2. TFIDF (fit_transform() on our training data)
# 3. TFIDF test (transform() on test data)
# 4. Calcualte the cosin similarity between objects using tfidf
#
# #### Import libraries/modules below:

# %%
import pickle
import re
import pandas as pd
import surprise
from surprise import KNNWithMeans
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import NormalPredictor
from surprise import KNNBaseline
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import BaselineOnly
from surprise import CoClustering
from surprise import SlopeOne
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise.reader import Reader
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from Mod_5_functions import pickle_file,open_pickle

# %% [markdown]
# **Import test and train data:**

# %%
user_reviews_train = open_pickle('Data/train_data')
user_reviews_test = open_pickle('Data/test_data')

# %% [markdown]
# **TFIDF:**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(0,3))
tfidf_matrix = vectorizer.fit_transform(user_reviews_train.rev_comp_reviews_corrections_new)

# %% [markdown]
# **Cosine Similarity:**

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarities = cosine_similarity(tfidf_matrix,Y=None,dense_output=False)

# %%
results = {} 
for idx, row in user_reviews_train.iterrows(): #iterates through all the rows
    similar_zip = sorted(list(zip(cosine_similarities[idx].indices,cosine_similarities[idx].data)),
                         key=lambda tup: tup[1], reverse=True)
    similar_indices = [i[0] for i in sorted(similar_zip,key = lambda tupe: tupe[1], reverse=True)][1:]
    
    similar_items = [user_reviews_train['rev_company_name'][i] for i in similar_indices]
    results[row['rev_company_name']] = similar_items

# %%
pickle_file(results,'Data/Cosine_similarity_train')
# Out:
# 'Pickled object!'

# %%
results['Peloton']
# Out:
# ['Equinox East 63rd Street',
#  'Greenhouse Holistic - CLOSED',
#  'Pure Barre - New York Union Square',
#  'Sal Anthony’s Movement Salon - CLOSED',
#  'Physique 57',
#  'SWERVE Fitness',
#  'Planet Fitness - Manhattan - Harlem Malcolm X Blvd. - CLOSED',
#  'Coban’s Muay Thai Camp - MOVED',
#  'Tiger Schulmann’s Mixed Martial Arts',
#  'Blink Fitness - Noho',
#  '92nd Street Y',
#  'Equinox East 63rd Street',
#  'Equinox East 44th Street',
#  'Aerial Arts NYC',
#  'Bodhi Fitness Center',
#  'Iyengar Yoga Institute of New York',
#  'Y7 Studio Union Square',
#  'Rumble Boxing',
#  'Peloton',
#  'Equinox Brooklyn Heights',
#  'Metropolitan Pool and Recreation Center',
#  'Chelsea Piers Fitness - Chelsea',
#  '24 Hour Fitness - Kew Gardens',
#  'Sivananda Ashram Yoga Ranch',
#  'Church Street Boxing Gym',
#  'Body & Pole',
#  'Willspace',
#  'New York Health & Racquet Club',
#  'iLoveKickboxing- Chelsea NYC',
#  'Alycea Ungaro’s Real Pilates',
#  'Recreation Center 54',
#  'Y7 Studio Flatiron',
#  'Flywheel Sports Upper West Side',
#  'Alvin Ailey American Dance Theater',
#  'Pure Barre - Bronxville',
#  'Kosciuszko Pool',
#  'New York Sports Clubs - CLOSED',
#  'Z Club NY',
#  'Barry’s Bootcamp Chelsea',
#  'Synergy Fitness Clubs - CLOSED',
#  'Body By Simone',
#  'New York Health & Racquet Club',
#  'Body Conceptions by Mahri',
#  'Stripxpertease',
#  'Exhale Flatiron',
#  'Adam Sanford Fitness - CLOSED',
#  'SKY TING YOGA',
#  'NY Best Kickboxing',
#  'Prospect Park Branch YMCA',
#  'Peloton',
#  'Shadowbox',
#  'Blink Fitness - Junction',
#  'Asphalt Green - Upper East Side',
#  'Bari Studio - CLOSED',
#  'Yoga Spa',
#  'Loom Yoga',
#  'Montauk Salt Cave',
#  'TMPL',
#  'CrossFit NYC: The Black Box',
#  'Blink Fitness - Sunset Park',
#  'Equinox Tribeca',
#  'Method Fitness',
#  'Physique 57',
#  'Club Fitness',
#  'Tone House',
#  'Barry’s Bootcamp Tribeca',
#  'NY Best Kickboxing',
#  'Crunch Fitness - 34th Street',
#  'Coban’s Muay Thai Camp',
#  'Crunch Fitness - 19th Street',
#  'Ailey Extension',
#  'Studio 360 - CLOSED',
#  'Synergy Fitness Clubs - CLOSED',
#  'Crunch Fitness - 38th Street',
#  'Jivamukti Yoga Center',
#  'Refine Method',
#  'Jewel City Yoga',
#  'Overthrow Boxing Club',
#  'Crunch Fitness - Union Square',
#  'Planet Fitness - Brooklyn - Duffield',
#  'I.AM.YOU Studio',
#  'OrangeTheory Fitness',
#  'Manhattan Plaza Health Club',
#  'Y7 Studio Flatiron',
#  'New York Yoga',
#  'SLT - MOVED',
#  'SLT Soho',
#  'Crunch Fitness - Park Slope',
#  'Power Studios',
#  'The Training Lab',
#  'CityRow - Union Square',
#  'BRICK Grand Central',
#  'Pop Physique',
#  'Steps On Broadway',
#  'Fhitting Room',
#  'Equinox Bryant Park',
#  'New York Sports Clubs',
#  'Peloton',
#  'SacredWaters',
#  'Peloton | Tread Studio',
#  'Body Space Fitness',
#  'Renzo Gracie Academy',
#  'Exhale Central Park South',
#  'NY Best Kickboxing',
#  'Cyc Fitness',
#  'The Bar Method - CLOSED',
#  'Brooklyn Boulders',
#  'Tangerine',
#  'House of Movement',
#  'Shadowbox',
#  'Aquamom',
#  'Refine Method',
#  'Barry’s Bootcamp Tribeca',
#  'Peloton',
#  'Bally Total Fitness',
#  'David Barton Gym - CLOSED',
#  'I Love Dance - Flushing',
#  'Awakening NY',
#  'CLAY Health Club + Spa - CLOSED',
#  'Equinox Brooklyn Heights',
#  'NDG Wellness Studio - CLOSED',
#  'CrossFit Hell’s Kitchen',
#  'Equinox West 76th Street',
#  'Blink Fitness - Sheepshead Bay',
#  'Equinox East 44th Street',
#  'Physique 57',
#  'Barry’s Bootcamp Tribeca',
#  'Church Street Boxing - Walker Street',
#  'Jivamukti Yoga Center',
#  'Gold’s Gym - CLOSED',
#  'New York Health & Racquet Club',
#  'Brooklyn Boulders',
#  'David Barton Gym - CLOSED',
#  'Solidcore',
#  'Retro Fitness',
#  'AquaSkills',
#  'Om Factory Yoga - CLOSED',
#  'Bari Studio - CLOSED',
#  'Yoga to the People - Hot Yoga',
#  'Brooklyn Bridge Boot Camp',
#  'Blink Fitness - Penn Station',
#  'Crunch Fitness - 59th Street',
#  'CKO Kickboxing Carroll Gardens',
#  'SLT Soho',
#  'Steps On Broadway',
#  'SLT E 67',
#  'SLT - MOVED',
#  'EDC Dance Studio - MOVED',
#  'Uplift Studios',
#  'Yoga to the People',
#  'Blink Fitness - Gates',
#  'Park Slope Armory YMCA',
#  'Exceed Physical Culture',
#  'Ishta Yoga',
#  'Row House',
#  'New York Sports Clubs',
#  'Exhale Gramercy',
#  'Exhale Upper East Side',
#  'Brooklyn Boulders Queensbridge',
#  'New York Sports Clubs',
#  'YogaWorks Westside - CLOSED',
#  'Cyc Fitness',
#  'SHOCKra Dance Studio - CLOSED',
#  'Fhitting Room',
#  'Club Fitness',
#  'Bikram Grand Central - CLOSED',
#  'Sacred Sounds Yoga',
#  'Modo Yoga NYC - West Village',
#  'SKY TING YOGA',
#  'Katonah Yoga NYC - RENOVATED',
#  'YogaWorks Soho',
#  'Bedford-Stuyvesant Branch YMCA',
#  'Circuit of Change',
#  'Radical MMA',
#  'LA Fitness',
#  'Bikram Yoga Bay Ridge',
#  'Fithouse Tribeca',
#  'Amerikick Martial Arts',
#  'Yoga High - MOVED',
#  'Bari Studio - CLOSED',
#  'Equinox Brooklyn Heights',
#  'Blink Fitness - Noho',
#  'Overthrow Boxing Club',
#  'modelFIT',
#  'Powerhouse Gym Fitness Center - CLOSED',
#  'Mendez Boxing',
#  'Rumble Boxing',
#  'Equinox Williamsburg',
#  'Uplift Studios',
#  'New York Jiu Jitsu - CLOSED',
#  'New York Sports Clubs',
#  'Blink Fitness - Chelsea',
#  'Sage Fitness Studios - MOVED',
#  'Djoniba Dance Centre',
#  'Equinox Park Avenue',
#  'NYSC Lab',
#  'Bedford-Stuyvesant Branch YMCA',
#  'Harbor Fitness',
#  'Pure Yoga',
#  'Planet Fitness - Brooklyn - Bushwick',
#  'David Barton Gym - CLOSED',
#  'Equinox Greenwich Avenue',
#  'The Bar Method',
#  'Blink Fitness - Harlem 125th',
#  'Pure Barre - Brooklyn Cobble Hill',
#  'Ailey Extension',
#  'New York Yoga',
#  'Bedford-Stuyvesant Branch YMCA',
#  'Uplift Studios',
#  'Uplift Studios',
#  'I.AM.YOU Studio',
#  'Bikram Yoga Queens - MOVED',
#  'Bedford-Stuyvesant Branch YMCA',
#  'Pure Barre - Brooklyn Williamsburg',
#  'Cyc Fitness',
#  'Yoga Union',
#  'Bikram Yoga Bay Ridge',
#  'SKY TING YOGA - Tribeca',
#  'Flywheel Sports Chelsea',
#  'Peloton',
#  'Exhale Gramercy',
#  'SWERVE Fitness',
#  'New York Sports Clubs',
#  'New York Sports Clubs',
#  'Movements Afoot - MOVED',
#  'New York Sports Clubs',
#  'Exceed Physical Culture',
#  'CrossFit NYC: The Black Box - MOVED',
#  'Strala Yoga - CLOSED',
#  'M Dance & Fitness',
#  'Rumble Boxing',
#  'Uplift Studios',
#  'Fitballet - CLOSED',
#  'Planet Fitness - Manhattan - 27th St.',
#  'Asphalt Green - Upper East Side',
#  'YogaCare',
#  'Destination Backcountry Adventures',
#  'YogaWorks Westside - CLOSED',
#  'Peloton',
#  'Broadway Dance Center',
#  'Blink Fitness - Bryant Park',
#  'The Art of Fitness - CLOSED',
#  'David Barton Gym - CLOSED',
#  'Studio 360 - CLOSED',
#  'Bikram Yoga NYC - CLOSED',
#  'New York Sports Clubs',
#  'Brooklyn Boulders',
#  'Reflections, Center for Conscious Living & Yoga',
#  'Bikram Yoga NYC',
#  'Physique 57',
#  'David Barton Gym - CLOSED',
#  'Inscape',
#  'Blink Fitness - 54th St',
#  'ANYA - CLOSED',
#  'Bad Ass Academy',
#  'Equinox Great Neck',
#  'Holding Space - CLOSED',
#  'Yoga Vida - Union Square',
#  'Bikram Yoga Union Square - CLOSED',
#  'New York Sports Clubs - CLOSED',
#  'Equinox East 53rd Street',
#  'Stripxpertease',
#  'Y7 Studio Williamsburg',
#  'Pop Physique',
#  'NYSC Lab',
#  'LA Fitness',
#  'Body By Simone',
#  'iLoveKickboxing- Chelsea NYC',
#  'Work Train Fight',
#  'Five Points Academy',
#  'West Side Branch YMCA',
#  'Crunch Fitness - Park Slope',
#  'Tiger Schulmann’s Mixed Martial Arts',
#  'Equinox East 44th Street',
#  'Mile High Run Club',
#  'Crunch Fitness - 34th Street',
#  'iLoveKickboxing- Chelsea NYC',
#  'Humming Puppy',
#  'iLoveKickboxing- Chelsea NYC',
#  'Bikram Yoga Park Slope - MOVED',
#  'Equinox West 76th Street',
#  'Tone House',
#  'New York Health & Racquet Club',
#  'Sheila Kelley S Factor',
#  'The Fhitting Room - CLOSED',
#  'Peloton',
#  'SLT E 67',
#  'Femme Body Fitness',
#  '24 Hour Fitness - Pelham Manor',
#  'Bally Total Fitness - CLOSED',
#  'Planet Fitness - Manhattan - Harlem Malcolm X Blvd. - CLOSED',
#  'New York Sports Clubs',
#  'Sheila Kelley S Factor',
#  'Equinox Brookfield Place',
#  'Peloton',
#  'The Spa on Wall Street',
#  'ANYA - CLOSED',
#  'Equinox Brookfield Place',
#  'New York Sports Clubs',
#  'Live Fit - CLOSED',
#  'New York Pilates - CLOSED',
#  'Flywheel Sports - Flatiron',
#  'EPIC Hybrid Training - CLOSED',
#  'Pure Barre - New York Upper East Side - Lexington & 88th',
#  'New York Health & Racquet Club',
#  'Exhale Gramercy',
#  'Orangetheory Midtown West',
#  'Urban Fitness Boutique - CLOSED',
#  'Dodge YMCA',
#  'Southbridge Fitness Center',
#  'Pure Yoga',
#  'Asphalt Green - Upper East Side',
#  'Equinox Wall Street',
#  'Brahman Yoga Harlem',
#  'Yoga In Tribeca',
#  'Exhale Meatpacking - CLOSED',
#  'New York Sports Clubs',
#  'YogaWorks Union Square - CLOSED',
#  'Blink Fitness - Sunset Park',
#  'Flywheel Sports Williamsburg',
#  'Hot On Yoga 27th',
#  'Physique 57',
#  'Pure Yoga',
#  'Yo Yoga!',
#  'Laughing Lotus Yoga Center',
#  'SWERVE Fitness',
#  'Gleason’s Gym',
#  'Yogamaya',
#  'Rhythm Ryde',
#  'Peloton',
#  'Bend & Bloom Yoga',
#  'Hit Factory Brooklyn',
#  'Row House',
#  'Studio Maya',
#  'Flywheel Sports Tribeca',
#  'Jumplife - CLOSED',
#  'NYSC Lab',
#  'INFighting Shape',
#  'New York Sports Club - CLOSED',
#  'Peloton',
#  'Xtend Barre Brooklyn Heights',
#  'Body Space Fitness',
#  'Bikram Yoga Astoria Queens',
#  'The Fhitting Room - CLOSED',
#  'Brooklyn Boulders',
#  'Ballet and Body',
#  '24 Hour Fitness - Tilden',
#  'Jivamukti Yoga Center',
#  'YogaWorks Soho',
#  'Marlene Meyerson JCC Manhattan',
#  'Katonah Yoga NYC - RENOVATED',
#  'Daya Yoga Studio',
#  'Physique 57',
#  'Cyc Fitness',
#  'NDG Wellness Studio - CLOSED',
#  'Barry’s Bootcamp Park Ave South',
#  'Body & Pole',
#  'Atlantis Sports Club - CLOSED',
#  'Bodē NYC - Upper West Side',
#  'Uplift Studios',
#  'Power Pilates - MOVED',
#  'Uplift Studios',
#  'Planet Fitness - Manhattan - Midtown West',
#  'Shadowbox',
#  'Sacred Studio',
#  'Green Fitness Studio',
#  'Rumble Boxing',
#  'Chelsea Piers Fitness - Chelsea',
#  'New York Sports Clubs',
#  'Yoga to the People - Hot Yoga',
#  'Femme Body Fitness',
#  'Church Street Boxing Gym',
#  'Y7 Studio - CLOSED',
#  'Daya Yoga Studio',
#  'F45 Lower East Side',
#  'Reflections, Center for Conscious Living & Yoga',
#  'Exhale Central Park South',
#  'Fierce Grace NYC',
#  'Crunch Fitness - 81st Street',
#  'Throwback Fitness',
#  'Radical MMA',
#  'Elite Bodies By J Ellis Jones - CLOSED',
#  'Row House',
#  'Vanderbilt Branch YMCA',
#  'Yoga To The People',
#  'Brooklyn Bridge Boot Camp',
#  'New York Sports Clubs',
#  'Orangetheory Fitness Manhattan - Chelsea',
#  'Ayurvedas World',
#  'Stripxpertease',
#  'David Barton Gym - CLOSED',
#  'New York Sports Clubs',
#  'New York Yoga',
#  'SWERVE Fitness',
#  'Big Apple Power Yoga - CLOSED',
#  'Equinox Williamsburg',
#  'Momentum Fitness',
#  'Physique 57',
#  'The Rock Health & Fitness Club',
#  'Yo Yoga!',
#  'Fhitting Room',
#  'SLT - MOVED',
#  'TMPL',
#  'Bikram Yoga South Slope - CLOSED',
#  'Yoga to the People',
#  'Jivamukti Yoga Center',
#  'Surfset New York City',
#  'Asphalt Green - Upper East Side',
#  'Wanderlust 108',
#  'Chelsea Piers Fitness - Chelsea',
#  'Bikram Yoga NYC - CLOSED',
#  'Broadway Dance Center',
#  'Y7 Studio Flatiron',
#  'Uplift Studios',
#  'Brooklyn Bodyburn - CLOSED',
#  'Mercedes Club',
#  'Fhitting Room',
#  'Rich Barretta Private Training',
#  'Mile High Run Club',
#  'Yoga Journal Conference Nyc',
#  'Vixen Workout NYC',
#  'Yoga to the People',
#  'Crunch Fitness - Park Slope',
#  'Brooklyn Martial Arts',
#  'Crunch Fitness - Bowery',
#  'The Happie House',
#  'NY Best Kickboxing',
#  'Lucille Roberts - Kings Highway',
#  'CityRow - Union Square',
#  'Barre3 - West Village',
#  'Synergy Fitness Clubs - CLOSED',
#  'Hari NYC',
#  'The Bar Method - CLOSED',
#  'Row House',
#  'Modo Yoga NYC - West Village',
#  'Equinox West 92nd Street',
#  'Blink Fitness - Sheepshead Bay',
#  'Bikram Yoga NYC - CLOSED',
#  'Bikram Grand Central - CLOSED',
#  'Flywheel Sports Chelsea',
#  'Hot On Yoga 27th',
#  'Flywheel Sports Chelsea',
#  'David Barton Gym - CLOSED',
#  'Cyc Fitness Chelsea',
#  'Physique 57',
#  'Yoga Shanti - CLOSED',
#  'Fhitting Room',
#  'East River Pilates',
#  'End Game Training - CLOSED',
#  '305 Fitness',
#  'David Barton Gym - CLOSED',
#  'Bikram Grand Central - CLOSED',
#  'New York Sports Clubs',
#  'Coliseum Gym & Fitness Center - CLOSED',
#  'Park Slope Yoga Center',
#  'New York Health & Racquet Club',
#  'EDC Dance Studio - MOVED',
#  'Bikram Yoga NYC - CLOSED',
#  'Your Body Your Machine',
#  'Reebok Sports Club/NY - MOVED',
#  '305 Fitness',
#  'David Barton Gym - MOVED',
#  'New York Sports Clubs',
#  'Peloton',
#  'Innerg Fitness - CLOSED',
#  'Church Street Boxing Gym',
#  'CLAY Health Club + Spa - CLOSED',
#  'Planet Fitness - Queens - Jamaica',
#  'Peloton',
#  'Pure Barre - New York Financial District',
#  'Christopher Harrison’s AntiGravity® LAB',
#  'The Bar Method - CLOSED',
#  'Laughing Lotus Yoga Center',
#  'The Cobra Club',
#  'Studio Maya',
#  'Kore - CLOSED',
#  'New York Sports Clubs - CLOSED',
#  'Abhaya Yoga Gowanus',
#  'Modo Yoga NYC - West Village',
#  'Crunch Fitness - Union Square',
#  'Ailey Extension',
#  '24 Hour Fitness - Broadway & Houston Ultra - CLOSED',
#  'Planet Fitness - Brooklyn - Flatbush',
#  'Pure Strength NYC - CLOSED',
#  'Brooklyn Pilates - RENOVATED',
#  'Laughing Lotus Yoga Center',
#  'Equinox Tribeca',
#  'Row House',
#  'Exhale Central Park South',
#  'Fitness Sanctuary',
#  'Jivamukti Yoga Center',
#  'New York Sports Clubs',
#  'Blink Fitness - Bryant Park',
#  'Physique 57',
#  'Pure Barre - Brooklyn Williamsburg',
#  '24 Hour Fitness - Broadway & Houston Ultra - CLOSED',
#  'Yoga & Fitness Herald Square',
#  'Yoga to the People',
#  'Flywheel Sports - Flatiron',
#  'New York Sports Clubs',
#  'New York Sports Clubs',
#  'Asphalt Green - Battery Park City',
#  'Equinox West 76th Street',
#  'Yoga People - CLOSED',
#  'Tribeca Heath & Fitness - MOVED',
#  'SWERVE Fitness',
#  'Peloton',
#  'Pilates On Fifth',
#  'Limelight Fitness',
#  'Uplift Studios',
#  'Bronx Branch YMCA',
#  'Studio 360 - CLOSED',
#  'Forum Fitness Club - CLOSED',
#  'Lyons Den Power Yoga - TriBeCa',
#  'New York Sports Clubs',
#  'iLoveKickboxing- Chelsea NYC',
#  'Crunch Fitness - 54th Street',
#  'lululemon athletica',
#  'Planet Fitness - Queens - Astoria',
#  'CKO Kickboxing Carroll Gardens',
#  'Studio 360 - CLOSED',
#  'Brooklyn Boulders',
#  'Bari Studio - CLOSED',
#  'Golden Bridge Yoga NYC - CLOSED',
#  'modelFIT',
#  'Barry’s Bootcamp Tribeca',
#  'AKT - Upper East Side',
#  'Jivamukti Yoga Center',
#  'Streamline Pilates Studio',
#  'SLT Flatiron',
#  'Y7 Studio Soho',
#  'New York Sports Clubs',
#  'CKO Kickboxing Park Slope',
#  'SWERVE Fitness',
#  'The Spa on Wall Street',
#  'BodyStrength Fitness',
#  'Yoga to the People - Hot Yoga',
#  'Foxy Fitness & Pole Training Studios',
#  'Flex Studios',
#  'Equinox West 76th Street',
#  'New York Sports Clubs',
#  'Tangerine',
#  'Peloton',
#  'New York Sports Clubs',
#  'HIIT BK - CLOSED',
#  'FLEX Studios',
#  'Exhale Soho - Temporarily Closed',
#  'Peloton',
#  'Hit Factory Brooklyn',
#  'BK Pilates',
#  'Kokushi Budo Institute',
#  'Pure Yoga',
#  'Chalk Gyms',
#  'Flywheel Sports NoMad',
#  'Tapout Fitness 106th Street',
#  'Flywheel Sports Tribeca',
#  'Om Factory Yoga - CLOSED',
#  'Sacred Sounds Yoga',
#  'Ditmas Fitness - CLOSED',
#  'Kettlebell Kickboxing',
#  'Peloton',
#  'Bally Fitness - CLOSED',
#  'Yoga Vida - Union Square',
#  'TITLE Boxing Club',
#  'Banana Skirt Productions',
#  'New York Sports Clubs',
#  'CorePower Yoga',
#  'New York Health & Racquet Club',
#  'Reebok Sports Club/NY - MOVED',
#  'Uplift Studios',
#  'New York Sports Clubs',
#  'NYC Dance Arts',
#  'Planet Fitness - Queens - Wyckoff',
#  'Barry’s Bootcamp Chelsea',
#  'CrossFit NYC: The Black Box',
#  'Mile High Run Club',
#  '24 Hour Fitness - 53rd St',
#  'Planet Fitness - Manhattan - 27th St.',
#  'Pop Physique',
#  'Big Six Fitness',
#  'Equinox East 63rd Street',
#  'Crossfit Bayside - CLOSED',
#  'New York Sports Clubs - CLOSED',
#  'Flywheel Sports - Flatiron',
#  'Crunch Fitness - Park Slope',
#  'Mid City Gym',
#  'Y7 Studio Flatiron',
#  'Equinox Columbus Circle',
#  'Five Points Academy',
#  'Bikram Yoga Yorktown',
#  'Body & Pole',
#  'SYNCStudio BKLYN',
#  'Jumplife - CLOSED',
#  'Yoga Union',
#  'Triple Threat Boot Camp',
#  'Barry’s Bootcamp Chelsea',
#  'Om Factory',
#  'Flex Studios',
#  'SHAKTIBARRE Williamsburg',
#  'Nap York - CLOSED',
#  'New York Sports Clubs',
#  'Crunch Fitness - 19th Street',
#  'Katonah Yoga NYC - RENOVATED',
#  'Brooklyn Athletic Club',
#  'Mile High Run Club',
#  'Brooklyn Boulders',
#  'Tone House',
#  'Rumble Boxing',
#  'New York Sports Clubs',
#  'Exhale Upper East Side',
#  'Shadowbox',
#  'OrangeTheory Fitness',
#  'Equinox West 76th Street',
#  'Blink Fitness - Astoria',
#  'Refine Method',
#  'Yogamaya',
#  'Barry’s Bootcamp NoHo',
#  'Equinox Wall Street',
#  'Peloton',
#  'ChaiseFitness',
#  'Equinox Park Avenue',
#  'Brooklyn Boulders',
#  'Kingsway Boxing Gym - CLOSED',
#  'Equinox East 54th Street',
#  'Bally Sports Clubs - CLOSED',
#  'Barre3 - West Village',
#  'Bedford-Stuyvesant Branch YMCA',
#  'Solace',
#  'Yogamaya',
#  'Exhale Central Park South',
#  'Yoga to the People',
#  'Exhale Gramercy',
#  'YogaCare',
#  'Aerial Arts NYC',
#  'SWERVE Fitness',
#  'Bikram Grand Central - CLOSED',
#  'New York Sports Clubs',
#  'TS Fitness',
#  'New York Sports Clubs',
#  'The Bar Method - CLOSED',
#  'Rumble Boxing',
#  'Peloton',
#  'Row House',
#  'CorePower Yoga',
#  'New York Sports Clubs',
#  'Exhale Upper East Side',
#  'Piel Canela Dance Company',
#  'TITLE Boxing Club',
#  'New York Sports Clubs',
#  'New York Sports Clubs',
#  'Angelo Consoli Personal Trainer',
#  'Shadowbox',
#  'Shadowbox',
#  'Equinox Gramercy',
#  'Equinox Wall Street',
#  'Brooklyn Athletic Club',
#  'Equinox Tribeca',
#  '24 Hour Fitness - 53rd St',
#  'Bikram Yoga South Slope - CLOSED',
#  'Equinox East 74th Street',
#  'Planet Fitness - Manhattan',
#  'Gold’s Gym - CLOSED',
#  'New York Sports Clubs',
#  'Crunch Fitness - Bowery',
#  'New York Sports Clubs',
#  'Flywheel Sports Tribeca',
#  'Barry’s Bootcamp NoHo',
#  'SWERVE Fitness',
#  'Modern Martial Arts',
#  'Yoga Tribe Brooklyn',
#  'iLoveKickboxing- Astoria',
#  'AQUA Studio',
#  'AQUA Studio',
#  'FlowCycle - CLOSED',
#  'Helium Aerial Dance - CLOSED',
#  '24 Hour Fitness - Tilden',
#  'NYSC Flagship Astor Place',
#  'Rumble Boxing',
#  'YogaWorks Soho',
#  'Robert Brace Personal Training Services',
#  'New York Sports Clubs',
#  'Equinox Columbus Circle',
#  'Awakening NY',
#  'New York Sports Clubs',
#  'Peloton',
#  'New York Sports Clubs',
#  'Crunch - New York',
#  'The Yoga Room',
#  'New York Sports Clubs',
#  'Sonic Yoga',
#  'Align Brooklyn',
#  'Overthrow Boxing Club',
#  'Bikram Yoga Union Square - CLOSED',
#  'Church Street Boxing Gym',
#  'Crunch - Richmond Hill',
#  'The Bar Method - CLOSED',
#  'Crank Indoor Cycling Studio',
#  'Crank Indoor Cycling Studio',
#  'Equinox SoHo',
#  'Pure Barre - New York Union Square',
#  'NYP Employee Fitness Center',
#  'NW Method',
#  'Tone House',
#  'ChaiseFitness - CLOSED',
#  'Yoga Vida - Union Square',
#  'Pilates Therapy & Wellness',
#  'Equinox Bryant Park',
#  'US Athletic Training Center',
#  'Uplift Studios',
#  'SLT Soho',
#  'YogaWorks Union Square - CLOSED',
#  'Row House',
#  'Move With Grace',
#  'Yoga La Vie',
#  'YogaWorks Soho',
#  'Harlem Branch YMCA',
#  'Physique 57',
#  'Barry’s Bootcamp Park Ave South',
#  'Hosh Yoga',
#  'Alvin Ailey American Dance Theater',
#  'Pure Barre - New York Upper West Side - Columbus Avenue',
#  'Reebok FitHub Union Square',
#  'Barry’s Bootcamp Tribeca',
#  'Mud And Lotus Training Center',
#  'Y7 Studio Union Square',
#  'Jivamukti Yoga Center',
#  'Greenpoint Branch YMCA',
#  'Yoga & Fitness Herald Square',
#  'Zen & Yoga',
#  'Peloton',
#  'NYSC Lab',
#  'BodyTonic Pilates Gymnasium',
#  'Bikram Yoga Harlem',
#  'Exhale Central Park South',
#  'Mile High Run Club',
#  'Urban Yoga Foundation',
#  'The Bar Method',
#  'Epic Hybrid Training',
#  'Body Reserve - CLOSED',
#  'Mile High Run Club',
#  'Solidcore',
#  'Peloton',
#  'Boom Fitness Park Ave - RENOVATED',
#  'Femme Body Fitness',
#  'Equinox Rockefeller Center',
#  'iLoveKickboxing- Harlem',
#  'Humming Puppy',
#  'Hot Spot Yoga',
#  'Flywheel Sports - Flatiron',
#  'YogaWorks Brooklyn',
#  'Equinox Wall Street',
#  '24 Hour Fitness - Madison Square Park Ultra',
#  'Warrior Fitness Boot Camp - CLOSED',
#  'Cyc Fitness',
#  'Barry’s Bootcamp NoHo',
#  'Yoga & Fitness Herald Square',
#  'Bikram Yoga NYC - CLOSED',
#  'New York Sports Clubs',
#  'Elite Gym',
#  'BK Pilates',
#  'Fhitting Room',
#  'Bikram Yoga NYC - CLOSED',
#  'Equinox Brookfield Place',
#  '24 Hour Fitness - 53rd St',
#  'Sonic Yoga',
#  'Arthur Murray Dance Studio',
#  'My Gym',
#  'Pure Barre - Brooklyn Williamsburg',
#  'Jivamukti Yoga Center',
#  'The Yoga Room',
#  'Brooklyn Yoga Collective - CLOSED',
#  'The Movement - CLOSED',
#  'New York Sports Clubs',
#  'Refine Method',
#  'Coban’s Muay Thai Camp',
#  'Bikram Yoga NYC - RENOVATED',
#  'Equinox East 43rd Street',
#  'Exceed Physical Culture',
#  'S&S Barbell',
#  'Equinox West 50th Street',
#  'McBurney Branch YMCA',
#  'Om Factory',
#  'Box & Flow',
#  'Hot Spot Yoga',
#  'The Bar Method',
#  'Beast Fitness Evolved',
#  'New York Sports Clubs - CLOSED',
#  'Yoga In Tribeca',
#  'Dance Cardio Plus',
#  'Unity Yoga',
#  'Crunch Fitness - 81st Street',
#  'Crunch - Flatbush',
#  'YogaWorks Union Square - CLOSED',
#  'Brooklyn Bodyburn - CLOSED',
#  'Banana Skirt Productions',
#  'Strala Yoga - CLOSED',
#  'Bikram Yoga Harlem',
#  'Clockwork Jiu Jitsu',
#  'Physique 57',
#  'Peloton',
#  'Uplift Studios',
#  'Mile High Run Club',
#  'Mile High Run Club',
#  'Ishta Yoga - MOVED',
#  'Harrison Strength & Fitness',
#  'Equinox Rockefeller Center',
#  'Sage Fitness Studios - MOVED',
#  'Flywheel Sports Upper West Side',
#  'New York Sports Clubs',
#  'New York Sports Clubs',
#  'Alana Life & Fitness',
#  'Y7 Studio - MOVED',
#  'Switch Playground',
#  'Flywheel Sports Williamsburg',
#  'New York Sports Clubs',
#  'Flywheel Sports - Flatiron',
#  'Physique 57',
#  'Krank-BK',
#  'Sacred Sounds Yoga',
#  'Cyc Fitness',
#  'TS Fitness - MOVED',
#  'Exhale Healing Arts',
#  'Kokushi Budo Institute',
#  'Blue Ocean Swimming',
#  'Hit Factory Brooklyn',
#  'Rumble Boxing',
#  'Prenatal Yoga Center',
#  'Equinox East 85th Street',
#  'Equinox East 74th Street',
#  'iLoveKickboxing- Astoria',
#  'Yoga to the People - Hot Yoga',
#  'Equinox Sports Club New York',
#  'Equinox Greenwich Avenue',
#  'SWERVE Fitness',
#  'Crunch - Crown Heights',
#  'The Bar Method - CLOSED',
#  'Lucille Roberts - Gun Hill - CLOSED',
#  'Crunch - CLOSED',
#  'Barry’s Bootcamp Park Ave South',
#  'Equinox West 76th Street',
#  'Y7 Studio Flatiron',
#  'Manny Cantor Center',
#  'Pilates Reforming New York',
#  'Stanton Street Yoga',
#  'New York Sports Clubs',
#  'Prema Yoga Brooklyn',
#  'Crunch Fitness - 19th Street',
#  'Cyc Fitness',
#  'Equinox East 85th Street',
#  'Blink Fitness - Chelsea',
#  'CorePower Yoga',
#  'NEOU',
#  'Body By Simone',
#  'Planet Fitness - Manhattan - Harlem Malcolm X Blvd. - CLOSED',
#  'Crunch Fitness - 34th Street',
#  'Bikram Yoga Harlem',
#  'Shadowbox',
#  'Barry’s Bootcamp Tribeca',
#  'Yoga Union',
#  'Crunch Fitness - 38th Street',
#  'The Bar Method - CLOSED',
#  'Om Factory',
#  'Blink Fitness - Gates',
#  'EPIC Hybrid Training - CLOSED',
#  'Y7 Studio Bryant Park',
#  'Blink Fitness - Bed Stuy',
#  'Area Yoga',
#  'CrossFit Hell’s Kitchen',
#  'Triomph Fitness, Health, & Wellness - MOVED',
#  'Yogamaya',
#  'Ice Nyc - CLOSED',
#  'Pure Barre - New York Financial District',
#  'Blink Fitness - Gates',
#  'iLoveKickboxing- Chelsea NYC',
#  'iLoveKickboxing- 43rd St NYC',
#  'United Tae Kwon Do Center - CLOSED',
#  'Tracy Anderson Method',
#  'Abhaya Yoga',
#  'New York Sports Clubs',
#  'Tangerine',
#  'Sacred Sounds Yoga',
#  'New York Sports Clubs',
#  'Uplift Studios',
#  'iLoveKickboxing- 43rd St NYC',
#  'Planet Fitness - Manhattan - 177th Street',
#  'Flywheel Sports Tribeca',
#  'Concrete Fitness - CLOSED',
#  'Pure Barre - New York Upper West Side - Columbus Avenue',
#  'Sheraton New York & Manhattan Health Clubs',
#  'Tangerine',
#  'New York Sports Clubs',
#  'Flywheel Sports Tribeca',
#  'Brooklyn Bodyburn - CLOSED',
#  'Blink Fitness - Bed Stuy',
#  'Dolphin Fitness Clubs',
#  'New York Sports Club - CLOSED',
#  'Equinox SoHo',
#  'Equinox Brooklyn Heights',
#  'Physique 57',
#  'Flywheel Sports - Flatiron',
#  'CrossFit SPOT',
#  'Mendez Boxing',
#  'modelFIT',
#  'Crunch - Norwood',
#  'Yoga People - CLOSED',
#  'Focus Integrated Fitness',
#  'Peloton | Tread Studio',
#  'R.U.S.H. Total Body Training - CLOSED',
#  'Flywheel Sports - Flatiron',
#  'AKT - Upper East Side',
#  'Boom Fitness - RENOVATED',
#  'Body Elite Gym',
#  'Solace',
#  'Torque Cycle + Strength - CLOSED',
#  'Blue Ocean Swimming',
#  'Lucille Roberts - Fulton - CLOSED',
#  'Anytime Fitness',
#  'Hot Spot Yoga',
#  'UFC Gym - CLOSED',
#  'goodyoga - CLOSED',
#  'ATOMIC Total Fitness',
#  'Krav Maga Institute NYC',
#  'Aquamom',
#  'trampoLEAN',
#  'BodyStrength Fitness',
#  'Brooklyn Yoga Collective - CLOSED',
#  'Ommvibe - CLOSED',
#  'Y7 Studio - CLOSED',
#  'CrossFit NYC: The Black Box',
#  'F45 Flatiron',
#  'Flex Hot Yoga',
#  'Overthrow Boxing Club',
#  'Alana Life & Fitness',
#  'Beyond Movement Fitness',
#  'TMPL',
#  'Pure Barre - Brooklyn Park Slope',
#  'New York Sports Clubs',
#  'Liberated Fitness',
#  'Yoga Vida - Union Square',
#  'Flywheel Sports - Flatiron',
#  'Stripxpertease',
#  'iLoveKickboxing- Chelsea NYC',
#  'Circuit of Change',
#  'Body By Simone',
#  'Body & Pole',
#  'SKY TING YOGA',
#  'Broadway Bodies',
#  'Metro Physical & Aquatic Therapy',
#  'Pure Barre - New York Union Square',
#  'Yoga to the People - CLOSED',
#  'DanceBody',
#  'Flywheel Sports Tribeca',
#  '305 Fitness',
#  'Chalk Gyms',
#  'Row House',
#  'CrossFit Hell’s Kitchen',
#  'Equinox East 74th Street',
#  'Uplift Studios',
#  'Barry’s Bootcamp NoHo',
#  'Throwback Fitness',
#  'Vanderbilt Branch YMCA',
#  'Brooklyn Crew - CLOSED',
#  'Pop Physique',
#  'Hot Spot Yoga',
#  'Exhale Flatiron',
#  'Sivananda Yoga Vedanta Center',
#  'DanceBody',
#  'Body By Simone',
#  'Warrior Fitness Boot Camp',
#  'Ishta Yoga',
#  'iLoveKickboxing- Harlem',
#  'New York Sports Clubs',
#  'Tone House',
#  'Sanctuary Yoga Studios - CLOSED',
#  'SLT Midtown - CLOSED',
#  'Stanton Street Yoga',
#  'The Bhakti Center',
#  'MNDFL Meditation Studio UES',
#  'Nicola Yvette',
#  'Fitballet - CLOSED',
#  'Switch Playground',
#  'UFC GYM NYC SoHo',
#  'Park Slope Yoga Center',
#  'Mile High Run Club',
#  'I.AM.YOU Studio',
#  'Modo Yoga NYC - Williamsburg',
#  'Harlem Wellness Center',
#  'Pilates Reforming New York - MOVED',
#  'Equinox Flatiron',
#  'Physique 57',
#  'Barrys Bootcamp UES',
#  'CONBODY',
#  'Equinox Flatiron',
#  'Crunch Fitness - 59th Street',
#  'Physique 57',
#  'Flywheel Sports Upper West Side',
#  'Synergy Fitness Clubs',
#  'Uplift Studios',
#  'The Bar Method - CLOSED',
#  'Tangerine',
#  ...]

# %%
cosine_df = pd.DataFrame(results)

# %%
cosine_df.head()
# Out:
#                                        14th Street Y  \
# 0  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 1                           Equinox East 63rd Street
# 2                      24 Hour Fitness - Kew Gardens
# 3                                      92nd Street Y
# 4                       Greenhouse Holistic - CLOSED
#
#                            21 Pilates                           212 Pilates  \
# 0            Equinox East 63rd Street              Equinox East 63rd Street
# 1        Greenhouse Holistic - CLOSED  Tiger Schulmann’s Mixed Martial Arts
# 2                           Loom Yoga        Coban’s Muay Thai Camp - MOVED
# 3            Equinox East 63rd Street    Pure Barre - New York Union Square
# 4  Iyengar Yoga Institute of New York          Greenhouse Holistic - CLOSED
#
#                 22nd Street Synergy Fitness - CLOSED  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                               Blink Fitness - Noho
# 3                     Coban’s Muay Thai Camp - MOVED
# 4                                      92nd Street Y
#
#                            24 Hour Fitness - 53rd St  \
# 0                           Equinox East 63rd Street
# 1                               Blink Fitness - Noho
# 2  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 3                     Synergy Fitness Clubs - CLOSED
# 4                           Church Street Boxing Gym
#
#                          24 Hour Fitness - Bay Shore  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                       Greenhouse Holistic - CLOSED
# 3               Tiger Schulmann’s Mixed Martial Arts
# 4                           Equinox East 44th Street
#
#                        24 Hour Fitness - Bensonhurst  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                               Blink Fitness - Noho
# 3                           Equinox East 63rd Street
# 4                                      92nd Street Y
#
#   24 Hour Fitness - Broadway & Houston Ultra - CLOSED  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                               Blink Fitness - Noho
# 3                           Equinox East 63rd Street
# 4                        Sivananda Ashram Yoga Ranch
#
#            24 Hour Fitness - Jamaica Center - CLOSED  \
# 0                           Church Street Boxing Gym
# 1                               Blink Fitness - Noho
# 2                           Equinox East 63rd Street
# 3  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 4                                      92nd Street Y
#
#                        24 Hour Fitness - Kew Gardens  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                               Blink Fitness - Noho
# 3                       Greenhouse Holistic - CLOSED
# 4                     Coban’s Muay Thai Camp - MOVED
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                         iLoveKickboxing- Carle Place  \
# 0                           Equinox East 63rd Street
# 1                       Greenhouse Holistic - CLOSED
# 2  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 3                               Blink Fitness - Noho
# 4               Tiger Schulmann’s Mixed Martial Arts
#
#                         iLoveKickboxing- Chelsea NYC  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                           Equinox East 63rd Street
# 3                               Blink Fitness - Noho
# 4               Tiger Schulmann’s Mixed Martial Arts
#
#              iLoveKickboxing- Financial District NYC  \
# 0                           Equinox East 63rd Street
# 1                       Greenhouse Holistic - CLOSED
# 2  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 3                     Coban’s Muay Thai Camp - MOVED
# 4               Tiger Schulmann’s Mixed Martial Arts
#
#                              iLoveKickboxing- Harlem  \
# 0                           Equinox East 63rd Street
# 1                     Coban’s Muay Thai Camp - MOVED
# 2                               Blink Fitness - Noho
# 3  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 4                       Greenhouse Holistic - CLOSED
#
#                          iLoveKickboxing- Lake Grove  \
# 0                           Equinox East 63rd Street
# 1                       Greenhouse Holistic - CLOSED
# 2  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 3               Tiger Schulmann’s Mixed Martial Arts
# 4                               Blink Fitness - Noho
#
#                                      inSHAPE Fitness  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                 Pure Barre - New York Union Square
# 3                           Equinox East 63rd Street
# 4                                        Body & Pole
#
#                                  lululemon athletica  \
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                       Greenhouse Holistic - CLOSED
# 3                     Coban’s Muay Thai Camp - MOVED
# 4                           Equinox East 63rd Street
#
#                                             modelFIT  \
# 0                           Equinox East 63rd Street
# 1                      Adam Sanford Fitness - CLOSED
# 2                       Greenhouse Holistic - CLOSED
# 3                 Pure Barre - New York Union Square
# 4  Planet Fitness - Manhattan - Harlem Malcolm X ...
#
#                   re:AB Pilates - CLOSED  \
# 0   Tiger Schulmann’s Mixed Martial Arts
# 1               Equinox East 63rd Street
# 2           Greenhouse Holistic - CLOSED
# 3  Sal Anthony’s Movement Salon - CLOSED
# 4                            Physique 57
#
#                                           trampoLEAN
# 0                           Equinox East 63rd Street
# 1  Planet Fitness - Manhattan - Harlem Malcolm X ...
# 2                       Greenhouse Holistic - CLOSED
# 3                     Coban’s Muay Thai Camp - MOVED
# 4                      24 Hour Fitness - Kew Gardens
#
# [5 rows x 1707 columns]

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, tfidf_matrix, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-0748cb9b6959> in <module>()
#       3 for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
#       4     # Perform cross validation
# ----> 5     results = cross_validate(algorithm, tfidf_matrix, measures=['RMSE'], cv=3, verbose=False)
#       6
#       7     # Get results & append algorithm name
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/surprise/model_selection/validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#      99                                            return_train_measures)
#     100                     for (trainset, testset) in cv.split(data))
# --> 101     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     102
#     103     (test_measures_dicts,
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     752             tasks = BatchedCalls(itertools.islice(iterator, batch_size),
#     753                                  self._backend.get_nested_backend(),
# --> 754                                  self._pickle_cache)
#     755             if len(tasks) == 0:
#     756                 # No more tasks available in the iterator: tell caller to stop.
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/joblib/parallel.py in __init__(self, iterator_slice, backend_and_jobs, pickle_cache)
#     208
#     209     def __init__(self, iterator_slice, backend_and_jobs, pickle_cache=None):
# --> 210         self.items = list(iterator_slice)
#     211         self._size = len(self.items)
#     212         if isinstance(backend_and_jobs, tuple):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/surprise/model_selection/validation.py in <genexpr>(.0)
#      96     cv = get_cv(cv)
#      97
# ---> 98     delayed_list = (delayed(fit_and_score)(algo, trainset, testset, measures,
#      99                                            return_train_measures)
#     100                     for (trainset, testset) in cv.split(data))
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/surprise/model_selection/split.py in split(self, data)
#      93         '''
#      94
# ---> 95         if self.n_splits > len(data.raw_ratings) or self.n_splits < 2:
#      96             raise ValueError('Incorrect value for n_splits={0}. '
#      97                              'Must be >=2 and less than the number '
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     645             return self.getnnz()
#     646         else:
# --> 647             raise AttributeError(attr + " not found")
#     648
#     649     def transpose(self, axes=None, copy=False):
#
# AttributeError: raw_ratings not found
